# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/good_reads_final.csv')
df.head()
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name                           author_page_url  \
# 0      74489    Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1     706255        Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    5618190  Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3      37871          José Donoso\n             /author/show/37871.Jos_Donoso
# 4      36122    Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
#
#    author_rating_count  author_review_count            birthplace  \
# 0                74399                 6268   United States\n
# 1              3726435               142704          Sweden\n
# 2                76496                 7975     United States\n
# 3                 5522                  489           Chile\n
# 4               291013                13453   United States\n
#
#    book_average_rating                                       book_fullurl  \
# 0                 4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                 4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                 3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                 4.14  https://www.goodreads.com/book/show/382975.The...
# 4                 4.01  https://www.goodreads.com/book/show/64207.Sorc...
#
#     book_id                                         book_title  genre_1  \
# 0    686717               \n      Murder on St. Mark's Place\n  Mystery
# 1   2429135          \n      The Girl with the Dragon Tattoo\n  Fiction
# 2  27833684                     \n      Tailored for Trouble\n  Romance
# 3    382975                \n      The Obscene Bird of Night\n  Fiction
# 4     64207  \n      Sorcery & Cecelia: or The Enchanted Ch...  Fantasy
#
#            genre_2  num_ratings  num_reviews pages     publish_date  score
# 0       Historical         5260          375   277             2000   3230
# 1          Mystery      2229163        65227   465      August 2005   3062
# 2     Contemporary         2151          391   354             2016   4585
# 3  Magical Realism         1844          173   438             1970   1533
# 4      Young Adult        17051         1890   326  April 15th 1988   2105

# %%
df.shape
# Out:
# (22891, 20)

# %%
#########################
#drop duplicate book names#
#############################

# %%
df['book_title'].is_unique
# Out:
# False

# %%
df.drop_duplicates(subset=['book_title'], keep='first',inplace=True)

# %%
df.shape
# Out:
# (16350, 20)

# %%
df['book_title'].is_unique
# Out:
# True

# %%
###########################
# delete_non_int in book ids
############################

# %%
df.dtypes
# Out:
# author_average_rating    float64
# author_gender             object
# author_genres             object
# author_id                  int64
# author_name               object
# author_page_url           object
# author_rating_count        int64
# author_review_count        int64
# birthplace                object
# book_average_rating      float64
# book_fullurl              object
# book_id                   object
# book_title                object
# genre_1                   object
# genre_2                   object
# num_ratings                int64
# num_reviews                int64
# pages                     object
# publish_date              object
# score                      int64
# dtype: object

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(2201)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 2196                   4.60          male
# 2197                   3.76          male
# 2198                   4.20          male
# 2199                   3.94          male
# 2200                   4.04          male
#
#                                   author_genres  author_id  \
# 0                           historical-fiction,      74489
# 1         literature-fiction,mystery-thrillers,     706255
# 2                                      romance,    5618190
# 3                               fiction,memoir,      37871
# 4                          young-adult,fantasy,      36122
# ...                                         ...        ...
# 2196                                   romance,    8119270
# 2197             literature-fiction,philosophy,     871368
# 2198     geography,social-sciences,non-fiction,    2774398
# 2199  historical-fiction,religion-spirituality,    2463923
# 2200                literature-fiction,history,      36378
#
#                 author_name                           author_page_url  \
# 0       Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1           Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2     Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3             José Donoso\n             /author/show/37871.Jos_Donoso
# 4       Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# ...                     ...                                       ...
# 2196     Jake Furie Lapin\n     /author/show/8119270.Jake_Furie_Lapin
# 2197         توفيق الحكيم\n                     /author/show/871368._
# 2198           جمال حمدان\n                    /author/show/2774398._
# 2199       محمد كامل حسين\n                    /author/show/2463923._
# 2200         Amin Maalouf\n           /author/show/36378.Amin_Maalouf
#
#       author_rating_count  author_review_count            birthplace  \
# 0                   74399                 6268   United States\n
# 1                 3726435               142704          Sweden\n
# 2                   76496                 7975     United States\n
# 3                    5522                  489           Chile\n
# 4                  291013                13453   United States\n
# ...                   ...                  ...                   ...
# 2196                  677                  204     United States\n
# 2197                61693                 7074           Egypt\n
# 2198                 3692                  348           Egypt\n
# 2199                 4689                  856           Egypt\n
# 2200                67938                 6254         Lebanon\n
#
#       book_average_rating                                       book_fullurl  \
# 0                    4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                    4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                    3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                    4.14  https://www.goodreads.com/book/show/382975.The...
# 4                    4.01  https://www.goodreads.com/book/show/64207.Sorc...
# ...                   ...                                                ...
# 2196                 4.56  https://www.goodreads.com/book/show/18519368-t...
# 2197                 3.85      https://www.goodreads.com/book/show/2392677._
# 2198                 4.34        https://www.goodreads.com/book/show/6076462
# 2199                 3.96      https://www.goodreads.com/book/show/2544247._
# 2200                 4.21  https://www.goodreads.com/book/show/142395.Sam...
#
#         book_id                                         book_title  \
# 0        686717               \n      Murder on St. Mark's Place\n
# 1       2429135          \n      The Girl with the Dragon Tattoo\n
# 2      27833684                     \n      Tailored for Trouble\n
# 3        382975                \n      The Obscene Bird of Night\n
# 4         64207  \n      Sorcery & Cecelia: or The Enchanted Ch...
# ...         ...                                                ...
# 2196   18519368                        \n      The Spice of Life\n
# 2197    2392677                                \n      أرني الله\n
# 2198  6076462']  \n      شخصية مصر: دراسة في عبقرية المكان - ال...
# 2199    2544247                               \n      قرية ظالمة\n
# 2200     142395                                \n      Samarkand\n
#
#             genre_1          genre_2  num_ratings  num_reviews pages  \
# 0           Mystery       Historical         5260          375   277
# 1           Fiction          Mystery      2229163        65227   465
# 2           Romance     Contemporary         2151          391   354
# 3           Fiction  Magical Realism         1844          173   438
# 4           Fantasy      Young Adult        17051         1890   326
# ...             ...              ...          ...          ...   ...
# 2196        Erotica    Adult Fiction          555          159   174
# 2197  Short Stories       Philosophy         4920          639   214
# 2198       Politics          History          926           67  3224
# 2199         Novels       Philosophy         3749          671   259
# 2200     Historical          Fiction        17269         1375   304
#
#           publish_date  score
# 0                 2000   3230
# 1          August 2005   3062
# 2                 2016   4585
# 3                 1970   1533
# 4      April 15th 1988   2105
# ...                ...    ...
# 2196  January 1st 2014  27580
# 2197              1953   5506
# 2198              1967   5545
# 2199              1954   5558
# 2200              1988   5580
#
# [2201 rows x 20 columns]

# %%
(df['book_id'][2197]).isdigit()
# Out:
# True

# %%
df.shape
# Out:
# (16350, 20)

# %%
id_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if df['book_id'][i].isdigit() == False:
        id_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df = df.drop(labels=id_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (16096, 20)

# %%
df.head(2201)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 2197                   3.76          male
# 2199                   3.94          male
# 2200                   4.04          male
# 2216                   4.21          male
# 2224                   3.87          male
#
#                                   author_genres  author_id  \
# 0                           historical-fiction,      74489
# 1         literature-fiction,mystery-thrillers,     706255
# 2                                      romance,    5618190
# 3                               fiction,memoir,      37871
# 4                          young-adult,fantasy,      36122
# ...                                         ...        ...
# 2197             literature-fiction,philosophy,     871368
# 2199  historical-fiction,religion-spirituality,    2463923
# 2200                literature-fiction,history,      36378
# 2216            politics,religion-spirituality,    1039846
# 2224                           social-sciences,    1452948
#
#                 author_name                           author_page_url  \
# 0       Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1           Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2     Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3             José Donoso\n             /author/show/37871.Jos_Donoso
# 4       Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# ...                     ...                                       ...
# 2197         توفيق الحكيم\n                     /author/show/871368._
# 2199       محمد كامل حسين\n                    /author/show/2463923._
# 2200         Amin Maalouf\n           /author/show/36378.Amin_Maalouf
# 2216  عبد الرحمن الكواكبي\n                    /author/show/1039846._
# 2224          صلاح الراشد\n                    /author/show/1452948._
#
#       author_rating_count  author_review_count                  birthplace  \
# 0                   74399                 6268         United States\n
# 1                 3726435               142704                Sweden\n
# 2                   76496                 7975           United States\n
# 3                    5522                  489                 Chile\n
# 4                  291013                13453         United States\n
# ...                   ...                  ...                         ...
# 2197                61693                 7074                 Egypt\n
# 2199                 4689                  856                 Egypt\n
# 2200                67938                 6254               Lebanon\n
# 2216                 8378                 1438  Syrian Arab Republic\n
# 2224                 4809                  589            \n  Kuwait\n
#
#       book_average_rating                                       book_fullurl  \
# 0                    4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                    4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                    3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                    4.14  https://www.goodreads.com/book/show/382975.The...
# 4                    4.01  https://www.goodreads.com/book/show/64207.Sorc...
# ...                   ...                                                ...
# 2197                 3.85      https://www.goodreads.com/book/show/2392677._
# 2199                 3.96      https://www.goodreads.com/book/show/2544247._
# 2200                 4.21  https://www.goodreads.com/book/show/142395.Sam...
# 2216                 4.21      https://www.goodreads.com/book/show/2312458._
# 2224                 3.90      https://www.goodreads.com/book/show/2422709._
#
#        book_id                                         book_title  \
# 0       686717               \n      Murder on St. Mark's Place\n
# 1      2429135          \n      The Girl with the Dragon Tattoo\n
# 2     27833684                     \n      Tailored for Trouble\n
# 3       382975                \n      The Obscene Bird of Night\n
# 4        64207  \n      Sorcery & Cecelia: or The Enchanted Ch...
# ...        ...                                                ...
# 2197   2392677                                \n      أرني الله\n
# 2199   2544247                               \n      قرية ظالمة\n
# 2200    142395                                \n      Samarkand\n
# 2216   2312458         \n      طبائع الاستبداد ومصارع الاستعباد\n
# 2224   2422709                          \n      كيف تخطط لحياتك\n
#
#             genre_1               genre_2  num_ratings  num_reviews pages  \
# 0           Mystery            Historical         5260          375   277
# 1           Fiction               Mystery      2229163        65227   465
# 2           Romance          Contemporary         2151          391   354
# 3           Fiction       Magical Realism         1844          173   438
# 4           Fantasy           Young Adult        17051         1890   326
# ...             ...                   ...          ...          ...   ...
# 2197  Short Stories            Philosophy         4920          639   214
# 2199         Novels            Philosophy         3749          671   259
# 2200     Historical               Fiction        17269         1375   304
# 2216       Politics            Nonfiction         7859         1376   157
# 2224      Self Help  International Dev...         1638          214   192
#
#          publish_date  score
# 0                2000   3230
# 1         August 2005   3062
# 2                2016   4585
# 3                1970   1533
# 4     April 15th 1988   2105
# ...               ...    ...
# 2197             1953   5506
# 2199             1954   5558
# 2200             1988   5580
# 2216             1900   7231
# 2224             2001   8426
#
# [2201 rows x 20 columns]

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(135)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 130                   4.00          male
# 131                   3.97          male
# 132                   3.82        female
# 133                   4.11        female
# 134                   3.97        female
#
#                              author_genres  author_id            author_name  \
# 0                      historical-fiction,      74489    Victoria Thompson\n
# 1    literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                 romance,    5618190  Mimi Jean Pamfiloff\n
# 3                          fiction,memoir,      37871          José Donoso\n
# 4                     young-adult,fantasy,      36122    Patricia C. Wrede\n
# ..                                     ...        ...                    ...
# 130                     mystery-thrillers,       2384      Janet Evanovich\n
# 131                    literature-fiction,       3780      James Patterson\n
# 132                           young-adult,      21911   Melissa de la Cruz\n
# 133                       fiction,romance,       1265          Jane Austen\n
# 134                    literature-fiction,       7128         Jodi Picoult\n
#
#                               author_page_url  author_rating_count  \
# 0        /author/show/74489.Victoria_Thompson                74399
# 1           /author/show/706255.Stieg_Larsson              3726435
# 2    /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3               /author/show/37871.Jos_Donoso                 5522
# 4         /author/show/36122.Patricia_C_Wrede               291013
# ..                                        ...                  ...
# 130         /author/show/2384.Janet_Evanovich              3157987
# 131         /author/show/3780.James_Patterson              5327117
# 132     /author/show/21911.Melissa_de_la_Cruz               594206
# 133             /author/show/1265.Jane_Austen              5182376
# 134            /author/show/7128.Jodi_Picoult              3288833
#
#      author_review_count            birthplace  book_average_rating  \
# 0                   6268   United States\n                     4.02
# 1                 142704          Sweden\n                     4.13
# 2                   7975     United States\n                   3.99
# 3                    489           Chile\n                     4.14
# 4                  13453   United States\n                     4.01
# ..                   ...                   ...                  ...
# 130               134950     United States\n                   3.99
# 131               260208     United States\n                   4.15
# 132                31552                  \n                   3.95
# 133               141593         England\n                     4.55
# 134               196552     United States\n                   3.97
#
#                                           book_fullurl   book_id  \
# 0    https://www.goodreads.com/book/show/686717.Mur...    686717
# 1    https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2    https://www.goodreads.com/book/show/27833684-t...  27833684
# 3    https://www.goodreads.com/book/show/382975.The...    382975
# 4    https://www.goodreads.com/book/show/64207.Sorc...     64207
# ..                                                 ...       ...
# 130  https://www.goodreads.com/book/show/6048530-fi...   6048530
# 131  https://www.goodreads.com/book/show/13139.Scho...     13139
# 132  https://www.goodreads.com/book/show/6267237-th...   6267237
# 133  https://www.goodreads.com/book/show/14905.The_...     14905
# 134  https://www.goodreads.com/book/show/3720975-ha...   3720975
#
#                                             book_title      genre_1  \
# 0                 \n      Murder on St. Mark's Place\n      Mystery
# 1            \n      The Girl with the Dragon Tattoo\n      Fiction
# 2                       \n      Tailored for Trouble\n      Romance
# 3                  \n      The Obscene Bird of Night\n      Fiction
# 4    \n      Sorcery & Cecelia: or The Enchanted Ch...      Fantasy
# ..                                                 ...          ...
# 130                   \n      Finger Lickin' Fifteen\n      Mystery
# 131                     \n      School's Out—Forever\n  Young Adult
# 132                      \n      The Van Alen Legacy\n   Paranormal
# 133                      \n      The Complete Novels\n      Romance
# 134                         \n      Handle with Care\n      Fiction
#
#              genre_2  num_ratings  num_reviews pages       publish_date  score
# 0         Historical         5260          375   277               2000   3230
# 1            Mystery      2229163        65227   465        August 2005   3062
# 2       Contemporary         2151          391   354               2016   4585
# 3    Magical Realism         1844          173   438               1970   1533
# 4        Young Adult        17051         1890   326    April 15th 1988   2105
# ..               ...          ...          ...   ...                ...    ...
# 130          Fiction        75408         3985   308               2009  16363
# 131          Fantasy       108397         3242   409               2006  17846
# 132      Young Adult        62718         1521   369               2009  18890
# 133         Classics        23605          618  1344  January 28th 1813  19609
# 134     Contemporary       103721         7833   453               2009  21020
#
# [135 rows x 20 columns]

# %%
####################
## remove book title that is not in ASCII table
####################

# %%
book_title_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if df['book_title'][i].isascii() == False:
        book_title_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df = df.drop(labels=book_title_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (15835, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(132)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 127                   3.91        female
# 128                   4.45        female
# 129                   4.13        female
# 130                   4.00          male
# 131                   3.82        female
#
#                              author_genres  author_id            author_name  \
# 0                      historical-fiction,      74489    Victoria Thompson\n
# 1    literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                 romance,    5618190  Mimi Jean Pamfiloff\n
# 3                          fiction,memoir,      37871          José Donoso\n
# 4                     young-adult,fantasy,      36122    Patricia C. Wrede\n
# ..                                     ...        ...                    ...
# 127               science-fiction-fantasy,      15873       Cornelia Funke\n
# 128                               fiction,    1077326         J.K. Rowling\n
# 129  literature-fiction,mystery-thrillers,    2001717    Daphne du Maurier\n
# 130                     mystery-thrillers,       2384      Janet Evanovich\n
# 131                           young-adult,      21911   Melissa de la Cruz\n
#
#                               author_page_url  author_rating_count  \
# 0        /author/show/74489.Victoria_Thompson                74399
# 1           /author/show/706255.Stieg_Larsson              3726435
# 2    /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3               /author/show/37871.Jos_Donoso                 5522
# 4         /author/show/36122.Patricia_C_Wrede               291013
# ..                                        ...                  ...
# 127         /author/show/15873.Cornelia_Funke               704947
# 128          /author/show/1077326.J_K_Rowling             21098703
# 129    /author/show/2001717.Daphne_du_Maurier               496484
# 130         /author/show/2384.Janet_Evanovich              3157987
# 131     /author/show/21911.Melissa_de_la_Cruz               594206
#
#      author_review_count             birthplace  book_average_rating  \
# 0                   6268    United States\n                     4.02
# 1                 142704           Sweden\n                     4.13
# 2                   7975      United States\n                   3.99
# 3                    489            Chile\n                     4.14
# 4                  13453    United States\n                     4.01
# ..                   ...                    ...                  ...
# 127                30005          Germany\n                     3.96
# 128               516169   United Kingdom\n                     4.74
# 129                30160   United Kingdom\n                     4.22
# 130               134950      United States\n                   3.99
# 131                31552                   \n                   3.95
#
#                                           book_fullurl   book_id  \
# 0    https://www.goodreads.com/book/show/686717.Mur...    686717
# 1    https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2    https://www.goodreads.com/book/show/27833684-t...  27833684
# 3    https://www.goodreads.com/book/show/382975.The...    382975
# 4    https://www.goodreads.com/book/show/64207.Sorc...     64207
# ..                                                 ...       ...
# 127  https://www.goodreads.com/book/show/100464.Dra...    100464
# 128  https://www.goodreads.com/book/show/862041.Har...    862041
# 129  https://www.goodreads.com/book/show/17899948-r...  17899948
# 130  https://www.goodreads.com/book/show/6048530-fi...   6048530
# 131  https://www.goodreads.com/book/show/6267237-th...   6267237
#
#                                             book_title     genre_1  \
# 0                 \n      Murder on St. Mark's Place\n     Mystery
# 1            \n      The Girl with the Dragon Tattoo\n     Fiction
# 2                       \n      Tailored for Trouble\n     Romance
# 3                  \n      The Obscene Bird of Night\n     Fiction
# 4    \n      Sorcery & Cecelia: or The Enchanted Ch...     Fantasy
# ..                                                 ...         ...
# 127                             \n      Dragon Rider\n     Fantasy
# 128              \n      Harry Potter Series Box Set\n     Fantasy
# 129                                  \n      Rebecca\n    Classics
# 130                   \n      Finger Lickin' Fifteen\n     Mystery
# 131                      \n      The Van Alen Legacy\n  Paranormal
#
#              genre_2  num_ratings  num_reviews pages       publish_date  score
# 0         Historical         5260          375   277               2000   3230
# 1            Mystery      2229163        65227   465        August 2005   3062
# 2       Contemporary         2151          391   354               2016   4585
# 3    Magical Realism         1844          173   438               1970   1533
# 4        Young Adult        17051         1890   326    April 15th 1988   2105
# ..               ...          ...          ...   ...                ...    ...
# 127          Fantasy        73386         2272   527  February 1st 1997  15248
# 128      Young Adult       224432         6881  4100               2007  15445
# 129          Fiction       376064        18329   449        August 1938  15851
# 130          Fiction        75408         3985   308               2009  16363
# 131      Young Adult        62718         1521   369               2009  18890
#
# [132 rows x 20 columns]

# %%
#######################################
##delete books with weried book pages
######################################

# %%
#count as book pages < 10 as invalid

# %%
# remove non_int pages
pages_index_list_to_drop_1 = []
for i in range(len(df['book_id'])):
    if df['pages'][i].isdigit() == False:
        pages_index_list_to_drop_1.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
pages_index_list_to_drop_1
# Out:
# [6244, 9981, 15708]

# %%
df = df.drop(labels=pages_index_list_to_drop_1, axis=0)

# %%
df.shape
# Out:
# (15832, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(6246)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 6241                   3.91          male
# 6242                   3.86          male
# 6243                   3.98          male
# 6244                   4.18        female
# 6245                   3.62        female
#
#                               author_genres  author_id  \
# 0                       historical-fiction,      74489
# 1     literature-fiction,mystery-thrillers,     706255
# 2                                  romance,    5618190
# 3                           fiction,memoir,      37871
# 4                      young-adult,fantasy,      36122
# ...                                     ...        ...
# 6241                               romance,   13536087
# 6242               science-fiction-fantasy,       8835
# 6243                           young-adult,    6449464
# 6244                               romance,    6535792
# 6245                    literature-fiction,       8268
#
#                       author_name  \
# 0             Victoria Thompson\n
# 1                 Stieg Larsson\n
# 2           Mimi Jean Pamfiloff\n
# 3                   José Donoso\n
# 4             Patricia C. Wrede\n
# ...                           ...
# 6241              Paige Laurens\n
# 6242                 Tim Powers\n
# 6243             Tracie Puckett\n
# 6244  Kimberly Stedronsky Adams\n
# 6245                 Zoë Heller\n
#
#                                      author_page_url  author_rating_count  \
# 0               /author/show/74489.Victoria_Thompson                74399
# 1                  /author/show/706255.Stieg_Larsson              3726435
# 2           /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3                      /author/show/37871.Jos_Donoso                 5522
# 4                /author/show/36122.Patricia_C_Wrede               291013
# ...                                              ...                  ...
# 6241             /author/show/13536087.Paige_Laurens                 1408
# 6242                    /author/show/8835.Tim_Powers                63860
# 6243             /author/show/6449464.Tracie_Puckett                24166
# 6244  /author/show/6535792.Kimberly_Stedronsky_Adams                 4956
# 6245                     /author/show/8268.Zo_Heller                24269
#
#       author_review_count              birthplace  book_average_rating  \
# 0                    6268     United States\n                     4.02
# 1                  142704            Sweden\n                     4.13
# 2                    7975       United States\n                   3.99
# 3                     489             Chile\n                     4.14
# 4                   13453     United States\n                     4.01
# ...                   ...                     ...                  ...
# 6241                  139       United States\n                   3.96
# 6242                 6052     United States\n                     3.94
# 6243                 1305  \n   United States\n                   4.23
# 6244                  715  \n   United States\n                   4.11
# 6245                 2729    United Kingdom\n                     3.71
#
#                                            book_fullurl   book_id  \
# 0     https://www.goodreads.com/book/show/686717.Mur...    686717
# 1     https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2     https://www.goodreads.com/book/show/27833684-t...  27833684
# 3     https://www.goodreads.com/book/show/382975.The...    382975
# 4     https://www.goodreads.com/book/show/64207.Sorc...     64207
# ...                                                 ...       ...
# 6241  https://www.goodreads.com/book/show/25004287-b...  25004287
# 6242  https://www.goodreads.com/book/show/142296.The...    142296
# 6243  https://www.goodreads.com/book/show/17876011-t...  17876011
# 6244  https://www.goodreads.com/book/show/26025172-roam  26025172
# 6245  https://www.goodreads.com/book/show/13258.What...     13258
#
#                                              book_title      genre_1  \
# 0                  \n      Murder on St. Mark's Place\n      Mystery
# 1             \n      The Girl with the Dragon Tattoo\n      Fiction
# 2                        \n      Tailored for Trouble\n      Romance
# 3                   \n      The Obscene Bird of Night\n      Fiction
# 4     \n      Sorcery & Cecelia: or The Enchanted Ch...      Fantasy
# ...                                                 ...          ...
# 6241                        \n      Beautiful Torment\n    New Adult
# 6242                         \n      The Anubis Gates\n      Fantasy
# 6243                 \n      The Webster Grove Series\n  Young Adult
# 6244                                     \n      Roam\n      Fantasy
# 6245  \n      What Was She Thinking? [Notes on a Sca...      Fiction
#
#               genre_2  num_ratings  num_reviews pages     publish_date  score
# 0          Historical         5260          375   277             2000   3230
# 1             Mystery      2229163        65227   465      August 2005   3062
# 2        Contemporary         2151          391   354             2016   4585
# 3     Magical Realism         1844          173   438             1970   1533
# 4         Young Adult        17051         1890   326  April 15th 1988   2105
# ...               ...          ...          ...   ...              ...    ...
# 6241          Romance          831           91   216             2015   1412
# 6242  Science Fiction        13174         1183   387             1983   6134
# 6243          Romance          660           42   395              NaN   1404
# 6244          Fantasy          703           92   332             2012   1693
# 6245     Contemporary        16890         1599   258    June 1st 2003   1964
#
# [6246 rows x 20 columns]

# %%
# remove pages < 10
pages_index_list_to_drop_2 = []
for i in range(len(df['book_id'])):
    if int(df['pages'][i]) < 10:
        pages_index_list_to_drop_2.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
pages_index_list_to_drop_2
# Out:
# [840,
#  1007,
#  1008,
#  1013,
#  1022,
#  1704,
#  1749,
#  2196,
#  2859,
#  2880,
#  3782,
#  3790,
#  4109,
#  5436,
#  6056,
#  6597,
#  7673,
#  8816,
#  9091,
#  9161,
#  9551,
#  9717,
#  9972,
#  9998,
#  11131,
#  11235,
#  11258,
#  11318,
#  12004,
#  12166,
#  12318,
#  12415,
#  14031,
#  14203,
#  15017,
#  15342,
#  15392,
#  15636,
#  15663,
#  15770]

# %%
df = df.drop(labels=pages_index_list_to_drop_2, axis=0)

# %%
df.shape
# Out:
# (15792, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   3.91        female
# 837                   3.75        female
# 838                   4.35        female
# 839                   3.92        female
# 840                   3.82        female
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# 4                      young-adult,fantasy,      36122    Patricia C. Wrede\n
# ..                                      ...        ...                    ...
# 836                        fiction,mystery,      22665    Diane Setterfield\n
# 837  literature-fiction,historical-fiction,       5918    Elizabeth Kostova\n
# 838             young-adult,animal-fiction,      27498          Erin Hunter\n
# 839              romance,mystery-thrillers,      16961         Linda Howard\n
# 840                                romance,    8072579          Layla Wolfe\n
#
#                               author_page_url  author_rating_count  \
# 0        /author/show/74489.Victoria_Thompson                74399
# 1           /author/show/706255.Stieg_Larsson              3726435
# 2    /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3               /author/show/37871.Jos_Donoso                 5522
# 4         /author/show/36122.Patricia_C_Wrede               291013
# ..                                        ...                  ...
# 836      /author/show/22665.Diane_Setterfield               264160
# 837       /author/show/5918.Elizabeth_Kostova               264518
# 838            /author/show/27498.Erin_Hunter               782385
# 839           /author/show/16961.Linda_Howard               402876
# 840          /author/show/8072579.Layla_Wolfe                 2971
#
#      author_review_count              birthplace  book_average_rating  \
# 0                   6268     United States\n                     4.02
# 1                 142704            Sweden\n                     4.13
# 2                   7975       United States\n                   3.99
# 3                    489             Chile\n                     4.14
# 4                  13453     United States\n                     4.01
# ..                   ...                     ...                  ...
# 836                25229      United Kingdom\n                   3.95
# 837                21445     United States\n                     3.78
# 838                28391                    \n                   4.43
# 839                20963     United States\n                     3.96
# 840                  834  \n   United States\n                   3.99
#
#                                           book_fullurl   book_id  \
# 0    https://www.goodreads.com/book/show/686717.Mur...    686717
# 1    https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2    https://www.goodreads.com/book/show/27833684-t...  27833684
# 3    https://www.goodreads.com/book/show/382975.The...    382975
# 4    https://www.goodreads.com/book/show/64207.Sorc...     64207
# ..                                                 ...       ...
# 836  https://www.goodreads.com/book/show/40440.The_...     40440
# 837  https://www.goodreads.com/book/show/30236962-t...  30236962
# 838  https://www.goodreads.com/book/show/336245.A_D...    336245
# 839  https://www.goodreads.com/book/show/420733.Kil...    420733
# 840  https://www.goodreads.com/book/show/22914552-b...  22914552
#
#                                             book_title  genre_1  \
# 0                 \n      Murder on St. Mark's Place\n  Mystery
# 1            \n      The Girl with the Dragon Tattoo\n  Fiction
# 2                       \n      Tailored for Trouble\n  Romance
# 3                  \n      The Obscene Bird of Night\n  Fiction
# 4    \n      Sorcery & Cecelia: or The Enchanted Ch...  Fantasy
# ..                                                 ...      ...
# 836                      \n      The Thirteenth Tale\n  Fiction
# 837                            \n      The Historian\n  Fiction
# 838                         \n      A Dangerous Path\n  Fantasy
# 839                            \n      Kill and Tell\n  Romance
# 840                         \n      Bad To The Bones\n  Romance
#
#               genre_2  num_ratings  num_reviews pages         publish_date  \
# 0          Historical         5260          375   277                 2000
# 1             Mystery      2229163        65227   465          August 2005
# 2        Contemporary         2151          391   354                 2016
# 3     Magical Realism         1844          173   438                 1970
# 4         Young Adult        17051         1890   326      April 15th 1988
# ..                ...          ...          ...   ...                  ...
# 836           Mystery       245905        20719   406                 2006
# 837        Historical       223836        15165   704                   by
# 838           Animals        32174          862   313                 2005
# 839           Romance        11297          369   305     January 1st 1998
# 840  See top shelves…          177           36   224  September 29th 2014
#
#      score
# 0     3230
# 1     3062
# 2     4585
# 3     1533
# 4     2105
# ..     ...
# 836  27127
# 837  47938
# 838   1430
# 839   1233
# 840   1398
#
# [841 rows x 20 columns]

# %%
#######################################
##delete genres that is "see top shelves"
#######################################

# %%
'see' in df['genre_1'][1]
# Out:
# False

# %%
genres_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if 'See' in df['genre_1'][i] or 'See' in df['genre_2'][i]:
        genres_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
#genres_index_list_to_drop

# %%
df = df.drop(labels=genres_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (15380, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   3.91        female
# 837                   3.75        female
# 838                   4.35        female
# 839                   3.92        female
# 840                   4.13          male
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# 4                      young-adult,fantasy,      36122    Patricia C. Wrede\n
# ..                                      ...        ...                    ...
# 836                        fiction,mystery,      22665    Diane Setterfield\n
# 837  literature-fiction,historical-fiction,       5918    Elizabeth Kostova\n
# 838             young-adult,animal-fiction,      27498          Erin Hunter\n
# 839              romance,mystery-thrillers,      16961         Linda Howard\n
# 840                                fiction,    8381790         Max Cummings\n
#
#                               author_page_url  author_rating_count  \
# 0        /author/show/74489.Victoria_Thompson                74399
# 1           /author/show/706255.Stieg_Larsson              3726435
# 2    /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3               /author/show/37871.Jos_Donoso                 5522
# 4         /author/show/36122.Patricia_C_Wrede               291013
# ..                                        ...                  ...
# 836      /author/show/22665.Diane_Setterfield               264160
# 837       /author/show/5918.Elizabeth_Kostova               264518
# 838            /author/show/27498.Erin_Hunter               782385
# 839           /author/show/16961.Linda_Howard               402876
# 840         /author/show/8381790.Max_Cummings                  206
#
#      author_review_count                birthplace  book_average_rating  \
# 0                   6268       United States\n                     4.02
# 1                 142704              Sweden\n                     4.13
# 2                   7975         United States\n                   3.99
# 3                    489               Chile\n                     4.14
# 4                  13453       United States\n                     4.01
# ..                   ...                       ...                  ...
# 836                25229        United Kingdom\n                   3.95
# 837                21445       United States\n                     3.78
# 838                28391                      \n                   4.43
# 839                20963       United States\n                     3.96
# 840                   83  \n   United States\n                     3.94
#
#                                           book_fullurl   book_id  \
# 0    https://www.goodreads.com/book/show/686717.Mur...    686717
# 1    https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2    https://www.goodreads.com/book/show/27833684-t...  27833684
# 3    https://www.goodreads.com/book/show/382975.The...    382975
# 4    https://www.goodreads.com/book/show/64207.Sorc...     64207
# ..                                                 ...       ...
# 836  https://www.goodreads.com/book/show/40440.The_...     40440
# 837  https://www.goodreads.com/book/show/30236962-t...  30236962
# 838  https://www.goodreads.com/book/show/336245.A_D...    336245
# 839  https://www.goodreads.com/book/show/420733.Kil...    420733
# 840  https://www.goodreads.com/book/show/22751611-l...  22751611
#
#                                             book_title  genre_1  \
# 0                 \n      Murder on St. Mark's Place\n  Mystery
# 1            \n      The Girl with the Dragon Tattoo\n  Fiction
# 2                       \n      Tailored for Trouble\n  Romance
# 3                  \n      The Obscene Bird of Night\n  Fiction
# 4    \n      Sorcery & Cecelia: or The Enchanted Ch...  Fantasy
# ..                                                 ...      ...
# 836                      \n      The Thirteenth Tale\n  Fiction
# 837                            \n      The Historian\n  Fiction
# 838                         \n      A Dangerous Path\n  Fantasy
# 839                            \n      Kill and Tell\n  Romance
# 840                            \n      Liberty Belle\n      War
#
#              genre_2  num_ratings  num_reviews pages      publish_date  score
# 0         Historical         5260          375   277              2000   3230
# 1            Mystery      2229163        65227   465       August 2005   3062
# 2       Contemporary         2151          391   354              2016   4585
# 3    Magical Realism         1844          173   438              1970   1533
# 4        Young Adult        17051         1890   326   April 15th 1988   2105
# ..               ...          ...          ...   ...               ...    ...
# 836          Mystery       245905        20719   406              2006  27127
# 837       Historical       223836        15165   704                by  47938
# 838          Animals        32174          862   313              2005   1430
# 839          Romance        11297          369   305  January 1st 1998   1233
# 840    Adult Fiction           33           16    84              2014    398
#
# [841 rows x 20 columns]

# %%
##########################################
##delete books which names are not in letters
##########################################

# %%
eng_names_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if 'See' in df['genre_1'][i] or 'See' in df['genre_2'][i]:
        eng_names_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df['book_title'][840]
# Out:
# '\n      Liberty Belle\n'

# %%
df['book_title'][840].strip('\n').strip().replace(" ", "")
# Out:
# 'LibertyBelle'

# %%
import re
book_title_list = []
for i in range(len(df['book_title'])):
    #book_title_list.append(df['book_title'][i].strip('\n').strip().replace(" ", ""))
    book_title_list.append(re.sub(r'[^\w\s]', '',df['book_title'][i].strip('\n').strip().replace(" ", "")))
book_title_list
# Out:
# ['MurderonStMarksPlace',
#  'TheGirlwiththeDragonTattoo',
#  'TailoredforTrouble',
#  'TheObsceneBirdofNight',
#  'SorceryCeceliaorTheEnchantedChocolatePot',
#  '30DaysofNightVol1',
#  'StalkMe',
#  'BonkTheCuriousCouplingofScienceandSex',
#  'KissoftheVampire',
#  'LeavingParadise',
#  'Firefight',
#  'LokisWolves',
#  'DevilinWinter',
#  'Mockingjay',
#  'Island',
#  'DirtyRoss',
#  'Screwups',
#  'PullMeUnder',
#  'StrengthoftheMate',
#  'TequilaMockingbird',
#  'OfLastResort',
#  'SlowBurn',
#  'ComplementaryColors',
#  'MarkofCain',
#  'WoodScrewsNails',
#  'BeautyAndTheBookworm',
#  'BadInfluence',
#  'TheUnderstatementoftheYear',
#  'TheOnlyOneWhoKnows',
#  'Payoff',
#  'Reawakening',
#  'PersonalSecrets',
#  'TheHouseonHancockHill',
#  'TimberPackChronicles',
#  'RemnantACaldwellFeximalWhyborneGriffinMystery',
#  'TheRiverLeith',
#  'Turning16',
#  'ToughLove',
#  'StoriesBeneathOurSkin',
#  'BeneaththeStain',
#  'FairPlay',
#  '127AnICoSAnthology',
#  'WolfinGucciLoafers',
#  'Bloodline',
#  'BeingSawyerKnight',
#  'Salvation',
#  'RackRuin',
#  'Control',
#  'LastFirstKiss',
#  'AHuntedMan',
#  'AForbiddenRumspringa',
#  'NotJustFriends',
#  'BetterThanChance',
#  'TheShearingGun',
#  'OnlyLove',
#  'LoveisaStranger',
#  'RedDirtHeart2',
#  'StaywithMe',
#  'NothingSpecial',
#  'SomethingLikeSpring',
#  'ForgetMeNot',
#  'Ethan',
#  'Queers',
#  'OffsideChance',
#  'ReliefValve',
#  'TheMatingofMichael',
#  'rock',
#  'Strain',
#  'WhenAlltheWorldSleeps',
#  'TroubletheWallflower',
#  'Enlightened',
#  'ShakingtheSugarTree',
#  'DaylightAgain',
#  'FullDisclosure',
#  'TheArtofBreathing',
#  'Take',
#  'BallChain',
#  'InsideOut',
#  'TheGatetoWomensCountry',
#  'TheSupernaturalist',
#  'StrangerinaStrangeLand',
#  'ShipBreaker',
#  'LogansRun',
#  'PlayerPiano',
#  'LucifersHammer',
#  'EarthAbides',
#  'PlanetoftheApes',
#  'Cell',
#  'AScannerDarkly',
#  'ShadesofGrey',
#  'TheDiamondAgeOrAYoungLadysIllustratedPrimer',
#  'TheDarkestMinds',
#  'RedRising',
#  'TheRunningMan',
#  'TheMartianChronicles',
#  'TheForeverWar',
#  'SwanSong',
#  'OntheBeach',
#  'ThePostman',
#  'StationEleven',
#  'AlasBabylon',
#  'TheChrysalids',
#  'Utopia',
#  'Enclave',
#  'ParableoftheSower',
#  'Feed',
#  'TheDispossessed',
#  'TheTrial',
#  'AcrosstheUniverse',
#  'TheHouseoftheScorpion',
#  'AtlasShrugged',
#  'TheChildrenofMen',
#  'Neuromancer',
#  'ACanticleforLeibowitz',
#  'Blindness',
#  'We',
#  'TheSelection',
#  'LifeAsWeKnewIt',
#  'BattleRoyale',
#  'Cinder',
#  'TheTimeMachine',
#  'WoolOmnibus',
#  'WorldWarZAnOralHistoryoftheZombieWar',
#  'OryxandCrake',
#  'NeverLetMeGo',
#  'Evermore',
#  'TheTwilightCollection',
#  'DragonRider',
#  'HarryPotterSeriesBoxSet',
#  'Rebecca',
#  'FingerLickinFifteen',
#  'TheVanAlenLegacy',
#  'TheCompleteNovels',
#  'HandlewithCare',
#  'TheFridayNightKnittingClub',
#  'LittleWomen',
#  'RunningwithScissors',
#  'SarahsKey',
#  'ATreeGrowsinBrooklyn',
#  'TheBellJar',
#  'TheUltimateHitchhikersGuidetotheGalaxy',
#  'TheJoyLuckClub',
#  'TheReader',
#  'WickedLovely',
#  'Eldest',
#  'TheRoad',
#  'Stargirl',
#  'TuesdayswithMorrie',
#  'TheReturnoftheKing',
#  'TheLostSymbol',
#  'Marked',
#  'BloodPromise',
#  'ThreeCupsofTeaOneMansMissiontoPromotePeaceOneSchoolataTime',
#  'ThePillarsoftheEarth',
#  'TheOtherBoleynGirl',
#  'PrideandPrejudiceandZombies',
#  'TheMemoryKeepersDaughter',
#  'Pretties',
#  'TheMadnessofLordIanMackenzie',
#  'SlavetoSensation',
#  'TheDarkestNight',
#  'PushingtheLimits',
#  'ThisHeartofMine',
#  'BridgetJonessDiary',
#  'PracticeMakesPerfect',
#  'WaitforYou',
#  'ThePerfectPlay',
#  'LoverEternal',
#  'ForeverMine',
#  'RockChick',
#  'FallenTooFar',
#  'PlayingforKeeps',
#  'Wallbanger',
#  'BetMe',
#  'CanYouKeepaSecret',
#  'NakedinDeath',
#  'ShatterMe',
#  'TheBride',
#  'TheSummerITurnedPretty',
#  'Significance',
#  'AKingdomofDreams',
#  'Matched',
#  'FlatOutLove',
#  'ReasontoBreathe',
#  'TheBronzeHorseman',
#  'MemoirsofaGeisha',
#  'Hopeless',
#  'OntheIsland',
#  'AWalktoRemember',
#  'HushHush',
#  'GonewiththeWind',
#  'GabrielsInferno',
#  'Easy',
#  'BaredtoYou',
#  'FiftyShadesofGrey',
#  'Icons',
#  'PODs',
#  'NobodyButUs',
#  'Prophecy',
#  'Unremembered',
#  'TheVoice',
#  'BetweentheDevilandtheDeepBlueSea',
#  'Spellcaster',
#  'Crash',
#  'TheChaosofStars',
#  'Invisibility',
#  'Spirit',
#  'Unbreakable',
#  'NotaDroptoDrink',
#  'StarCursed',
#  'Elegy',
#  'Altered',
#  'TheRunawayKing',
#  'TheCollector',
#  'PaperValentine',
#  'Dualed',
#  'PivotPoint',
#  'BreakingPoint',
#  'ThisIsWhatHappyLooksLike',
#  'SchoolSpirits',
#  'TheMadnessUnderneath',
#  'MyNameIsRapunzel',
#  'Antigoddess',
#  'TheColdestGirlinColdtown',
#  'TheseBrokenStars',
#  'OfTriton',
#  'Awaken',
#  'Sentinel',
#  'Taken',
#  'MILA20',
#  'The5thWave',
#  'TheBitterKingdom',
#  'LettheSkyFall',
#  'WithAllMySoul',
#  'TheArchived',
#  'Champion',
#  'EtiquetteEspionage',
#  'ShadowsintheSilence',
#  'DarkTriumph',
#  'TheMoonandMore',
#  'TheEssence',
#  'SweetPeril',
#  'TheProgram',
#  'Asunder',
#  'Splintered',
#  'TheGoddessInheritance',
#  'JustOneDay',
#  'UnitedWeSpy',
#  'ShadowhuntersandDownworldersAMortalInstrumentsReader',
#  'Everbound',
#  'IfIShouldDie',
#  'SiegeandStorm',
#  'TheRising',
#  'CrownofMidnight',
#  'Goddess',
#  'Light',
#  'Requiem',
#  'Sever',
#  'ThroughtheEverNight',
#  'Boundless',
#  'Allegiant',
#  'Dearest',
#  'BloodandSalt',
#  'Dumplin',
#  'Shutter',
#  'NoneoftheAbove',
#  'BecomingJinn',
#  'UnderaPaintedSky',
#  'TheVanishingThrone',
#  'ABookofSpiritsandThieves',
#  'Mechanica',
#  'TheSummerofChasingMermaids',
#  'Vendetta',
#  'ThingsWeKnowbyHeart',
#  'Rook',
#  'Reawakened',
#  'TheStoryspinner',
#  'TheImmortalHeights',
#  'TheWallsAroundUs',
#  'AWickedThing',
#  'DaughterofDeepSilence',
#  'TheStartofMeandYou',
#  'InkandBone',
#  'AnotherDay',
#  'MadeYouUp',
#  'HiddenHuntress',
#  'StandOff',
#  'IllMeetYouThere',
#  'TheRestofUsJustLiveHere',
#  'TheWitchHunter',
#  'TheConspiracyofUs',
#  'Ignite',
#  'DeadofWinter',
#  'AlltheRage',
#  'Magonia',
#  'Frostfire',
#  'LairofDreams',
#  'TheGirlatMidnight',
#  'LiarsInc',
#  'Invaded',
#  'MyHeartandOtherBlackHoles',
#  'ShadowScale',
#  'IceLikeFire',
#  'AlltheBrightPlaces',
#  'TheWrathandtheDawn',
#  'CarryOn',
#  'TheWinnersCrime',
#  'RedQueen',
#  'SeeingRed',
#  'HoneyQueen',
#  'GoneGirl',
#  'ProphecyoftheSisters',
#  'AegisRising',
#  'DragonLightning',
#  'HellsTeeth',
#  'Bitterblue',
#  'MindGames',
#  'OntheEdge',
#  'UnholyGhosts',
#  'TheMagiciansNephew',
#  'KushielsDart',
#  'TheDarkDivine',
#  'NorthofBeautiful',
#  'Birthmarked',
#  'PeterADarkenedFairytale',
#  'TheUnbecomingofMaraDyer',
#  'Incarceron',
#  'StolenALettertoMyCaptor',
#  'TheVGirl',
#  'StrangeAngels',
#  'Firelight',
#  'PrincessAcademy',
#  'AnnaandtheFrenchKiss',
#  'BeautifulDisaster',
#  'EllaEnchanted',
#  'Shiver',
#  'IAmNumberFour',
#  'ThisSideoftheGrave',
#  'TheStressofHerRegard',
#  'SomeofYourBlood',
#  'SmokeandShadows',
#  'BittenSmitten',
#  'LiveGirls',
#  'CircusoftheDamned',
#  'TheDraculaTape',
#  'BlackSunRising',
#  'RealVampiresHaveCurves',
#  'IAmLegend',
#  'DarkDance',
#  'Fated',
#  'TheVampireQueensServant',
#  'TheLightattheEnd',
#  'NightPleasures',
#  'Draculas',
#  'Minion',
#  'VampireHunterD',
#  'AHiddenFire',
#  'TheVampireTapestry',
#  'MorrigansCross',
#  'Skinwalker',
#  'TheTravelingVampireShow',
#  '13Bullets',
#  'Nightwalker',
#  'Vampire',
#  'ChildrenoftheNight',
#  'ThoseWhoHunttheNight',
#  'SunglassesAfterDark',
#  'IfAngelsBurn',
#  'Dhampir',
#  'Raphael',
#  'OnceBittenTwiceShy',
#  'ThePassage',
#  'CovenantwiththeVampire',
#  'TheKeep',
#  'AlreadyDead',
#  'TheHunger',
#  'MidnightsDaughter',
#  'NiceGirlsDontHaveFangs',
#  'FullMoonRising',
#  'HowtoMarryaMillionaireVampire',
#  'AnnoDracula',
#  'CarpeJugulum',
#  'AQuickBite',
#  'NightWatch',
#  'Pandora',
#  'Necroscope',
#  'FevreDream',
#  'BloodsuckingFiends',
#  'SomeGirlsBite',
#  'UndeadandUnwed',
#  'TheStrain',
#  'Darkfever',
#  'LostSouls',
#  'ADiscoveryofWitches',
#  'DeadWitchWalking',
#  'KissofMidnight',
#  'MoonCalled',
#  'Carmilla',
#  'Sunshine',
#  'DeadUntilDark',
#  'LettheRightOneIn',
#  'Dracula',
#  'TheUnderneath',
#  'Chains',
#  'ThePlagueofDoves',
#  'FireflyLane',
#  'HumanSmokeTheBeginningsofWorldWarIItheEndofCivilization',
#  'VictoryofEagles',
#  'GenerationDead',
#  'WhenWillThereBeGoodNews',
#  'TheMiddlePlace',
#  'SkeletonsattheFeast',
#  'AFractionoftheWhole',
#  'BlackoutGirlGrowingUpandDryingOutinAmerica',
#  'SuchaPrettyFatOneNarcissistsQuesttoDiscoverIfHerLifeMakesHerAssLookBigorWhyPieIsNottheAnswer',
#  'TheRedLeatherDiaryReclaimingaLifeThroughthePagesofaLostJournal',
#  'TheBrokenWindow',
#  'ChasingHarryWinston',
#  '2666',
#  'TheLadyElizabeth',
#  'IWasToldTheredBeCake',
#  'Snuff',
#  'BetrayalonOrbis2',
#  'Impossible',
#  'AMercy',
#  'TheHereticsDaughter',
#  'UnluckyLuckyDays',
#  'ACurseDarkasGold',
#  'TheMiracleatSpeedyMotors',
#  'HoldTight',
#  'CertainGirls',
#  'OutliersTheStoryofSuccess',
#  'RodrickRules',
#  'AmericanWife',
#  'TheLikeness',
#  'Netherland',
#  'InDefenseofFoodAnEatersManifesto',
#  'Mudbound',
#  'SmallFavor',
#  'LovetheOneYoureWith',
#  'TheMonstersofTempleton',
#  'TheHourIFirstBelieved',
#  'OliveKitteridge',
#  'GripoftheShadowPlague',
#  'BelongtoMe',
#  'ThePigeonWantsaPuppy',
#  'DeweyTheSmallTownLibraryCatWhoTouchedtheWorld',
#  'CityofThieves',
#  'LittleBrother',
#  'WhenYouAreEngulfedinFlames',
#  'PaperTowns',
#  'PeopleoftheBook',
#  'UnaccustomedEarth',
#  'TheStoryofEdgarSawtelle',
#  'TheBattleoftheLabyrinth',
#  'TheLastLecture',
#  'TheTimeTravelersWife',
#  'FirstComesLove',
#  'TheDayBefore',
#  'EndlessSummer',
#  'TenTinyBreaths',
#  'WhatIDidntSay',
#  'RacingWithTheRain',
#  'IfILie',
#  'LoveUnscripted',
#  'OntheJellicoeRoad',
#  'RockMe',
#  'ForbidMe',
#  'Wanderlove',
#  'ThereYoullFindMe',
#  'StealingParker',
#  'SavingJune',
#  'ShutOut',
#  'SomethinglikeNormal',
#  'TheBoyWhoSneaksinMyBedroomWindow',
#  'TheMightyStorm',
#  'YouAgainstMe',
#  'TakeThisRegret',
#  'HowtoKillaRockStar',
#  'TheGlassCastle',
#  'AThousandSplendidSuns',
#  'SophieCarter',
#  'LosingIt',
#  'TheSweetGumTree',
#  'HeartsinDarkness',
#  'Almost',
#  'EpicFail',
#  'AmyRogersEpicDetour',
#  'Room',
#  'Effortless',
#  'CallumHarper',
#  'HeartonaChain',
#  'CrossMyHeart',
#  'MeBeforeYou',
#  'Forbidden',
#  'TheEdgeofNever',
#  'MyLifeNextDoor',
#  'ThirteenReasonsWhy',
#  'SqueesWonderfulBigGiantBookofUnspeakableHorrors',
#  'Nimona',
#  'Top10Vol1',
#  'WolverineOrigin',
#  'HyperboleandaHalfUnfortunateSituationsFlawedCopingMechanismsMayhemandOtherThingsThatHappened',
#  'GoodByeChunkyRice',
#  'TheInvisiblesVolume1SayYouWantaRevolution',
#  'DMZVol1OntheGround',
#  'Ronin',
#  'FireandFlight',
#  'Embroideries',
#  'TheMaxxVol1',
#  'MouseGuardFall1152',
#  'TheRabbisCat',
#  'ExMachinaVol1TheFirstHundredDays',
#  'XMenDaysofFuturePast',
#  'BatmanHush',
#  'AmericanVampireVol1',
#  'Shortcomings',
#  'AstroCityVol1LifeintheBigCity',
#  'TheUltimates',
#  'Blacksad',
#  'GhostintheShell',
#  'IdentityCrisis',
#  '100BulletsVol1FirstShotLastCall',
#  'TheDarkTowerTheGunslingerBorn',
#  'TheInventionofHugoCabret',
#  'EssexCounty',
#  'PyongyangAJourneyinNorthKorea',
#  'PlanetaryVolume1AllOvertheWorldandOtherStories',
#  'TheCrow',
#  'Stitches',
#  'BuffytheVampireSlayerTheLongWayHome',
#  'AContractWithGodandOtherTenementStories',
#  'LoneWolfandCubVol1TheAssassinsRoad',
#  'Epileptic',
#  'ChewVol1TastersChoice',
#  'AnyasGhost',
#  'TheUmbrellaAcademyVol1TheApocalypseSuite',
#  'AsterixtheGaul',
#  'FullmetalAlchemistVol1',
#  'Palestine',
#  'Daytripper',
#  'JimmyCorrigantheSmartestKidonEarth',
#  'UnderstandingComicsTheInvisibleArt',
#  'KingdomCome',
#  'AkiraVol1',
#  'AsteriosPolyp',
#  'HellboyVol1SeedofDestruction',
#  'WelcometoLovecraft',
#  'BlackHole',
#  'AmericanBornChinese',
#  'TheArrival',
#  'DeathNoteVol1Boredom',
#  'GhostWorld',
#  'PreacherVolume1GonetoTexas',
#  'BoneTheCompleteEdition',
#  'FunHomeAFamilyTragicomic',
#  'ScottPilgrimVolume1ScottPilgrimsPreciousLittleLife',
#  'TheWalkingDeadVol1DaysGoneBye',
#  'FablesVol1LegendsinExile',
#  'TheCompleteMaus',
#  'TheNaming',
#  'TheDry',
#  'MissMabelsSchoolforGirls',
#  'TheHoundofRowan',
#  'TheLastUnicorn',
#  'HereThereBeDragons',
#  'MayasMagicalAdventures',
#  'TheMistsofAvalon',
#  'SandrysBook',
#  'BeyondtheDeepwoods',
#  'TheEighthDay',
#  'TheAkhenatenAdventure',
#  'TheCrystalCave',
#  'TheLostYearsofMerlin',
#  'TuckEverlasting',
#  'TheSwordintheStone',
#  'ALittlePrincess',
#  'Dragonsong',
#  'TheMerchantofDeath',
#  'HalfMagic',
#  'TheBadBeginning',
#  'PawnofProphecy',
#  'TheFieldGuide',
#  'Matilda',
#  'Stormbreaker',
#  'TheThief',
#  'TheEyeoftheWorld',
#  'TheLookingGlassWars',
#  'MisterMonday',
#  'Redwall',
#  'LevenThumpsandtheGatewaytoFoo',
#  'SoYouWanttoBeaWizard',
#  'MidnightforCharlieBone',
#  'TheNeverendingStory',
#  'TheBookofThree',
#  'TheRuinsofGorlan',
#  'TheWonderfulWizardofOz',
#  'TheNameoftheWind',
#  'ThePrincessBride',
#  'TheMysteriousBenedictSociety',
#  'PeterandtheStarcatchers',
#  'BridgetoTerabithia',
#  'TheMazeRunner',
#  'TheAlchemyst',
#  'TheCityofEmber',
#  'HowlsMovingCastle',
#  'AWrinkleinTime',
#  'TheAmuletofSamarkand',
#  'Magyk',
#  'LeahontheOffbeat',
#  'HowtoRepairaMechanicalHeart',
#  'RageALoveStory',
#  'Adaptation',
#  'IfYouCouldBeMine',
#  'Shine',
#  'MaybeWithaChanceofCertainty',
#  'Torn',
#  'DontLetMeGo',
#  'WhatHappenedtoLaniGarver',
#  'HardLove',
#  'SoHardtoSay',
#  'OutofthePocket',
#  'TheOrderofthePoisonOak',
#  'TotallyJoe',
#  'Teeth',
#  'Sprout',
#  'SomedayThisPainWillBeUsefultoYou',
#  'Tricks',
#  'HistoryIsAllYouLeftMe',
#  'WeetzieBat',
#  'MyMostExcellentYear',
#  'AlmostPerfect',
#  'OneManGuy',
#  'NaomiandElysNoKissList',
#  'TheVastFieldsofOrdinary',
#  'Proxy',
#  'EverythingLeadstoYou',
#  'SuicideNotes',
#  'EmpressoftheWorld',
#  'WeAretheAnts',
#  'AskthePassengers',
#  'TheGentlemansGuidetoViceandVirtue',
#  'TheMiseducationofCameronPost',
#  'Hero',
#  'TheSongofAchilles',
#  'AnnieonMyMind',
#  'AristotleandDanteDiscovertheSecretsoftheUniverse',
#  'TheWickedGarden',
#  'TheGirlwithNoShadow',
#  'Shame',
#  'AmongOthers',
#  'HereonEarth',
#  'ATriptotheStars',
#  'TheWarofDonEmmanuelsNetherParts',
#  'MissPeregrinesHomeforPeculiarChildren',
#  'TheStoriesofEvaLuna',
#  'DanceDanceDance',
#  'CronopiosandFamas',
#  'TheMagicToyshop',
#  'MrPenumbras24HourBookstore',
#  'Swamplandia',
#  'OfBeesandMist',
#  'TheTempleofMyFamiliar',
#  'MamaDay',
#  'DictionaryoftheKhazarsMaleEdition',
#  'TheMistressofSpices',
#  'Steppenwolf',
#  'TheTigersWife',
#  'ShoelessJoe',
#  'MemoriesofMyMelancholyWhores',
#  'DonaFlorandHerTwoHusbands',
#  'BigFish',
#  'TheHummingbirdsDaughter',
#  'TheMilagroBeanfieldWar',
#  'TheAngelsGame',
#  'TheTinDrum',
#  'TheStrangeandBeautifulSorrowsofAvaLavender',
#  'TheSnowChild',
#  'EvenCowgirlsGettheBlues',
#  'BlessMeUltima',
#  'ThePassion',
#  'TheParticularSadnessofLemonCake',
#  'IfonaWintersNightaTraveler',
#  'LittleBig',
#  'TheGolemandtheJinni',
#  'TheBriefWondrousLifeofOscarWao',
#  'WintersTale',
#  'LifeofPi',
#  'HoudiniHeart',
#  'EverythingIsIlluminated',
#  'ThePeachKeeper',
#  'Ficciones',
#  'TheNightCircus',
#  'TheMasterandMargarita',
#  'LikeWaterforChocolate',
#  'UnseenMessages',
#  'FromSandandAsh',
#  'Undeserving',
#  'TheFireBetweenHighLo',
#  'Cunning',
#  'ListentoMe',
#  'LastMile',
#  'FallenCrestHome',
#  'BecauseofMissBridgerton',
#  'TheDirtonNinthGrave',
#  'StuckUpSuit',
#  'SwearonThisLife',
#  'HardBall',
#  'FightingSolitude',
#  'HallowedGround',
#  'WickedHeart',
#  'Ryder',
#  'WorthItAll',
#  'UntilJune',
#  'Demand',
#  'SugarDaddy',
#  'TheLie',
#  'ThePlayerandthePixie',
#  'HappilyEverNinja',
#  'TheProtector',
#  'Moonshot',
#  'BreakingHer',
#  'Infini',
#  'PuckedOver',
#  'Charged',
#  'RoomHate',
#  'Defenseless',
#  'ReapersFire',
#  'MidnightLily',
#  'Dirty',
#  'Soulless',
#  'WickedSexyLiar',
#  'TheGoal',
#  'Aced',
#  'Appealed',
#  'WalkTwoMoons',
#  'AClockworkOrange',
#  'TessoftheDUrbervilles',
#  'ATaleofTwoCities',
#  'InvisibleMan',
#  'TheIliad',
#  'TheGuernseyLiteraryandPotatoPeelPieSociety',
#  'TheWestingGame',
#  'TheirEyesWereWatchingGod',
#  'JonathanLivingstonSeagull',
#  'EatPrayLove',
#  'ThePoisonwoodBible',
#  'MadameBovary',
#  'TheGrapesofWrath',
#  'TheAdventuresofTomSawyer',
#  'HeartofDarkness',
#  'TheSecretLifeofBees',
#  'EndersGame',
#  'TheCrucible',
#  'Outlander',
#  'ThingsFallApart',
#  'TheCalloftheWild',
#  'OneFlewOvertheCuckoosNest',
#  'TheOldManandtheSea',
#  'TheCanterburyTales',
#  'TheShack',
#  'TheGoldenCompass',
#  'WatershipDown',
#  'CrimeandPunishment',
#  'TheStranger',
#  'TheBoyintheStripedPajamas',
#  'NumbertheStars',
#  'WaterforElephants',
#  'TheLovelyBones',
#  'TheAlchemist',
#  'Frankenstein',
#  'FlowersforAlgernon',
#  'WutheringHeights',
#  'TheHelp',
#  'TheCuriousIncidentoftheDogintheNightTime',
#  'TheScarletLetter',
#  'TheLittlePrince',
#  'Macbeth',
#  'TheBookThief',
#  'AnimalFarm',
#  'Night',
#  'TheCatcherintheRye',
#  'JaneEyre',
#  'LordoftheFlies',
#  'TheDiaryofaYoungGirl',
#  'TheOutsiders',
#  'TheGreatGatsby',
#  'ToKillaMockingbird',
#  'TheWomaninWhite',
#  'AbsolutionbyMurder',
#  'Atonement',
#  'SomeDangerInvolved',
#  'Medicus',
#  'TheMeaningofNight',
#  'Labyrinth',
#  'WhereShadowsDance',
#  'TheCurseofthePharaohs',
#  'TheNovicesTale',
#  'TheGameofKings',
#  'TheClubDumas',
#  'TheWinterQueen',
#  'CompanyofLiars',
#  'TheBoneChurch',
#  'DarkRoadtoDarjeeling',
#  'FoucaultsPendulum',
#  'AFatalWaltz',
#  'TheGame',
#  'DevilinaBlueDress',
#  'DeceptiononSableHill',
#  'BlindJustice',
#  'CuttotheQuick',
#  'Possession',
#  'TheQueensMan',
#  'ABeautifulBlueDeath',
#  'AMurderousProcession',
#  'AConspiracyofPaper',
#  'MonksHood',
#  'Heartstone',
#  'TheSecretHistoryofthePinkCarnation',
#  'RomanBlood',
#  'HotelontheCornerofBitterandSweet',
#  'ATestofWills',
#  'TheHouseatRiverton',
#  'PardonableLies',
#  'HerRoyalSpyness',
#  'Fingersmith',
#  'TheDanteClub',
#  'Pompeii',
#  'Child44',
#  'TheSilverPigs',
#  'TheFaceofaStranger',
#  'TheAngelofDarkness',
#  'AnInstanceoftheFingerpost',
#  'TheSweetnessattheBottomofthePie',
#  'PerfumeTheStoryofaMurderer',
#  'TheDaughterofTime',
#  'TheThirteenthTale',
#  'TheHistorian',
#  'ADangerousPath',
#  'KillandTell',
#  'LibertyBelle',
#  'TheCornishTrilogyTheRebelAngelsWhatsBredintheBoneTheLyreofOrpheus',
#  'OrdinaryPeople',
#  'RabbitRedux',
#  'TheManWithoutQualities',
#  'TheAudacityofHopeThoughtsonReclaimingtheAmericanDream',
#  'WhatIstheWhat',
#  'JohnAdams',
#  'FastFoodNationTheDarkSideoftheAllAmericanMeal',
#  'WhiteTeeth',
#  'HouseofLeaves',
#  'EmpireFalls',
#  'Shantaram',
#  'CuttingforStone',
#  'TheHistoryofLove',
#  'TheCorrections',
#  'FreakonomicsARogueEconomistExplorestheHiddenSideofEverythingFreakonomics1',
#  'CloudAtlas',
#  'SnowFlowerandtheSecretFan',
#  'TheAmazingAdventuresofKavalierClay',
#  'TheDevilintheWhiteCityMurderMagicandMadnessattheFairThatChangedAmerica',
#  'BelCanto',
#  'Middlesex',
#  'CaddieWoodlawn',
#  'Aztec',
#  'TheCrimsonPetalandtheWhite',
#  'TheSource',
#  'TheLastKingdom',
#  'Lincoln',
#  'TheFarPavilions',
#  'SarahPlainandTall',
#  'TheCiderHouseRules',
#  'TheCompleteAubreyMaturinNovels5Volumes',
#  'London',
#  'TheFrenchLieutenantsWoman',
#  'ForeverAmber',
#  'NorthandSouth',
#  'TheFirstManinRome',
#  'TaiPan',
#  'Nefertiti',
#  'TheBirthofVenus',
#  'JonathanStrangeMrNorrell',
#  'Ivanhoe',
#  'WolfHall',
#  'Molokai',
#  'TheAgonyandtheEcstasy',
#  'FriedGreenTomatoesattheWhistleStopCafe',
#  'AlltheLightWeCannotSee',
#  'PopeJoan',
#  'TheScarletPimpernel',
#  'Exodus',
#  'Katherine',
#  'TheEnglishPatient',
#  'IClaudius',
#  'TheThreeMusketeers',
#  'ColdMountain',
#  'LonesomeDove',
#  'TheRedTent',
#  'DonQuixote',
#  'UncleTomsCabin',
#  'AllQuietontheWesternFront',
#  'WarandPeace',
#  'GoodnightMoon',
#  'Lolita',
#  'Catch22',
#  'OhThePlacesYoullGo',
#  'WheretheWildThingsAre',
#  'ThePictureofDorianGray',
#  'AlicesAdventuresinWonderlandThroughtheLookingGlass',
#  'TheGivingTree',
#  'TheAbsolutelyTrueDiaryofaPartTimeIndian',
#  'Flipped',
#  'FromtheMixedUpFilesofMrsBasilEFrankweiler',
#  'PippiLongstocking',
#  'TheSisterhoodoftheTravelingPants',
#  'ThePhantomTollbooth',
#  'AnneofGreenGables',
#  'VampireKisses',
#  'TheLuxe',
#  'AmongtheHidden',
#  'FearofFlying',
#  'TheLostHonorofKatharinaBlum',
#  'GhostStory',
#  'RollofThunderHearMyCry',
#  'TheOtherSideofMidnight',
#  'WarandRemembrance',
#  'MyNameIsAsherLev',
#  'RendezvouswithRama',
#  'TheExecutionersSong',
#  'TheSwordofShannara',
#  'AngleofRepose',
#  'TheMonsterattheEndofthisBook',
#  'TheRightStuff',
#  'TheDarkIsRising',
#  'KaneandAbel',
#  'TalesofaFourthGradeNothing',
#  'Deliverance',
#  'SidewaysStoriesfromWaysideSchool',
#  'TheHistoryofSexualityVolume1AnIntroduction',
#  'ADistantMirrorTheCalamitous14thCentury',
#  'TheBookofLaughterandForgetting',
#  'TheEssentialNerudaSelectedPoems',
#  'FrogandToadAreFriends',
#  'GravitysRainbow',
#  'TheGrassIsAlwaysGreenerovertheSepticTank',
#  'TheDayoftheJackal',
#  'AllthePresidentsMen',
#  'Orientalism',
#  'TheKillerAngels',
#  '84CharingCrossRoad',
#  'Ragtime',
#  'TheBlackPrince',
#  'HelterSkelterTheTrueStoryoftheMansonMurders',
#  'TinkerTailorSoldierSpy',
#  'ZenandtheArtofMotorcycleMaintenanceAnInquiryIntoValues',
#  'TheExorcist',
#  'BuryMyHeartatWoundedKneeAnIndianHistoryoftheAmericanWest',
#  'FearandLoathinginLasVegas',
#  'TheLostGirl',
#  'EchoofanEarthAngel',
#  'TheVampireHuntersDaughterCompleteCollection',
#  'FootballSweetheart',
#  'MarkoftheSeer',
#  'Chosen',
#  'TheSpringsweet',
#  'Obumbrate',
#  'EverShade',
#  'TheEarthPainter',
#  'SwitchTheLostKingdomsofKaribu',
#  'TheManyLivesofAverySnow',
#  'JessicaRulestheDarkSide',
#  'Fade',
#  'ProjectELE',
#  'GradeAStupid',
#  'WildesFire',
#  'TouchingSmoke',
#  'Afterlife',
#  'Charade',
#  'ForgedbyGreed',
#  'Ember',
#  'BurningBridges',
#  'Timepiece',
#  'DarkCompanion',
#  'Crewel',
#  'Endure',
#  'Dragonswood',
#  'Breathe',
#  'WitchBorn',
#  'Glitch',
#  'TheTreacheryofBeautifulThings',
#  'SomethingStrangeandDeadly',
#  'WickedFate',
#  'BorninFlames',
#  'Defiance',
#  'Flutter',
#  'Elsewhere',
#  'JurassicPark',
#  'SixEpicAdventureNovelsIntotheAmericasTheOrphanTrilogyTheWorldDuology',
#  'NineByNight',
#  'TheAlexandriaQuartet',
#  ...]

# %%
non_eng_book_index = []
for i in range(len(book_title_list)):
    if book_title_list[i].isalpha() == False:
        non_eng_book_index.append(i)
non_eng_book_index
# Out:
# [5,
#  36,
#  41,
#  56,
#  229,
#  230,
#  361,
#  418,
#  422,
#  500,
#  504,
#  505,
#  509,
#  510,
#  512,
#  515,
#  517,
#  522,
#  527,
#  532,
#  534,
#  536,
#  538,
#  544,
#  546,
#  551,
#  553,
#  556,
#  557,
#  558,
#  659,
#  828,
#  856,
#  872,
#  904,
#  938,
#  939,
#  949,
#  1009,
#  1013,
#  1017,
#  1033,
#  1043,
#  1070,
#  1102,
#  1206,
#  1226,
#  1268,
#  1296,
#  1315,
#  1333,
#  1389,
#  1430,
#  1509,
#  1558,
#  1560,
#  1580,
#  1616,
#  1617,
#  1644,
#  1683,
#  1703,
#  1727,
#  1742,
#  1763,
#  1790,
#  1852,
#  1953,
#  1979,
#  2028,
#  2076,
#  2127,
#  2174,
#  2222,
#  2288,
#  2295,
#  2298,
#  2299,
#  2301,
#  2306,
#  2331,
#  2383,
#  2404,
#  2501,
#  2533,
#  2546,
#  2556,
#  2576,
#  2717,
#  2754,
#  2831,
#  2836,
#  2874,
#  2880,
#  2895,
#  2902,
#  3084,
#  3124,
#  3139,
#  3148,
#  3172,
#  3179,
#  3251,
#  3324,
#  3325,
#  3326,
#  3327,
#  3328,
#  3329,
#  3330,
#  3331,
#  3332,
#  3333,
#  3334,
#  3335,
#  3336,
#  3337,
#  3338,
#  3339,
#  3340,
#  3341,
#  3342,
#  3343,
#  3344,
#  3345,
#  3346,
#  3347,
#  3348,
#  3349,
#  3350,
#  3351,
#  3352,
#  3353,
#  3354,
#  3355,
#  3356,
#  3357,
#  3358,
#  3359,
#  3360,
#  3361,
#  3362,
#  3363,
#  3364,
#  3365,
#  3366,
#  3367,
#  3368,
#  3369,
#  3370,
#  3371,
#  3372,
#  3373,
#  3374,
#  3375,
#  3376,
#  3377,
#  3378,
#  3379,
#  3380,
#  3381,
#  3382,
#  3384,
#  3385,
#  3386,
#  3387,
#  3388,
#  3428,
#  3472,
#  3517,
#  3654,
#  3723,
#  3724,
#  3730,
#  3731,
#  3749,
#  3842,
#  3966,
#  3972,
#  3980,
#  4028,
#  4146,
#  4164,
#  4182,
#  4192,
#  4216,
#  4223,
#  4231,
#  4414,
#  4439,
#  4542,
#  4575,
#  4628,
#  4633,
#  4677,
#  4686,
#  4688,
#  4749,
#  4770,
#  4774,
#  4784,
#  4786,
#  4796,
#  4797,
#  4800,
#  4801,
#  4815,
#  4817,
#  4819,
#  4921,
#  4936,
#  4965,
#  4982,
#  5063,
#  5105,
#  5129,
#  5133,
#  5170,
#  5249,
#  5253,
#  5348,
#  5409,
#  5411,
#  5419,
#  5526,
#  5527,
#  5529,
#  5531,
#  5543,
#  5553,
#  5562,
#  5576,
#  5586,
#  5587,
#  5593,
#  5594,
#  5619,
#  5643,
#  5666,
#  5772,
#  5780,
#  5786,
#  5855,
#  5861,
#  5864,
#  5866,
#  5868,
#  5872,
#  5874,
#  5879,
#  5883,
#  5885,
#  5887,
#  5888,
#  5892,
#  5893,
#  5899,
#  5901,
#  5902,
#  5906,
#  5907,
#  5910,
#  5913,
#  5914,
#  5920,
#  5921,
#  5923,
#  5925,
#  5928,
#  5930,
#  5932,
#  5935,
#  5936,
#  5940,
#  5943,
#  5958,
#  5961,
#  5968,
#  5976,
#  5991,
#  6066,
#  6121,
#  6163,
#  6191,
#  6197,
#  6199,
#  6216,
#  6222,
#  6399,
#  6448,
#  6559,
#  6624,
#  6627,
#  6642,
#  6751,
#  6835,
#  6838,
#  6844,
#  6899,
#  6929,
#  6968,
#  7029,
#  7044,
#  7050,
#  7058,
#  7077,
#  7124,
#  7161,
#  7192,
#  7196,
#  7206,
#  7211,
#  7278,
#  7288,
#  7334,
#  7358,
#  7368,
#  7384,
#  7394,
#  7426,
#  7551,
#  7564,
#  7657,
#  7691,
#  7711,
#  7730,
#  7757,
#  7817,
#  7840,
#  7957,
#  8060,
#  8081,
#  8130,
#  8138,
#  8156,
#  8171,
#  8196,
#  8239,
#  8260,
#  8262,
#  8279,
#  8296,
#  8308,
#  8318,
#  8329,
#  8335,
#  8340,
#  8345,
#  8378,
#  8381,
#  8451,
#  8481,
#  8494,
#  8511,
#  8529,
#  8547,
#  8667,
#  8673,
#  8703,
#  8766,
#  8768,
#  8881,
#  8897,
#  8898,
#  8921,
#  8947,
#  8967,
#  8994,
#  9038,
#  9047,
#  9059,
#  9153,
#  9263,
#  9312,
#  9320,
#  9483,
#  9500,
#  9507,
#  9553,
#  9642,
#  9652,
#  9661,
#  9692,
#  9728,
#  9828,
#  9872,
#  9882,
#  9986,
#  10062,
#  10111,
#  10127,
#  10173,
#  10200,
#  10210,
#  10300,
#  10305,
#  10310,
#  10314,
#  10334,
#  10342,
#  10348,
#  10360,
#  10361,
#  10362,
#  10493,
#  10556,
#  10654,
#  10698,
#  10717,
#  10749,
#  10773,
#  10810,
#  10817,
#  10829,
#  10839,
#  10906,
#  10931,
#  11030,
#  11194,
#  11272,
#  11276,
#  11334,
#  11349,
#  11350,
#  11385,
#  11455,
#  11512,
#  11514,
#  11525,
#  11534,
#  11535,
#  11536,
#  11538,
#  11542,
#  11547,
#  11551,
#  11567,
#  11622,
#  11715,
#  11717,
#  11720,
#  11857,
#  11907,
#  11926,
#  11932,
#  11937,
#  11941,
#  11948,
#  11950,
#  12020,
#  12022,
#  12024,
#  12025,
#  12073,
#  12093,
#  12095,
#  12111,
#  12211,
#  12262,
#  12291,
#  12304,
#  12351,
#  12375,
#  12379,
#  12381,
#  12395,
#  12401,
#  12411,
#  12431,
#  12444,
#  12629,
#  12636,
#  12666,
#  12698,
#  12699,
#  12745,
#  12791,
#  12814,
#  12825,
#  12830,
#  12838,
#  12840,
#  12844,
#  12863,
#  12931,
#  12934,
#  12936,
#  12937,
#  12942,
#  12945,
#  12947,
#  12949,
#  12951,
#  12953,
#  12954,
#  12959,
#  12960,
#  12965,
#  12968,
#  12970,
#  12971,
#  12972,
#  12982,
#  12997,
#  13007,
#  13092,
#  13151,
#  13164,
#  13166,
#  13168,
#  13170,
#  13175,
#  13184,
#  13214,
#  13227,
#  13261,
#  13398,
#  13424,
#  13430,
#  13451,
#  13473,
#  13483,
#  13484,
#  13488,
#  13498,
#  13508,
#  13518,
#  13535,
#  13564,
#  13757,
#  13774,
#  13780,
#  13787,
#  13813,
#  13846,
#  13927,
#  13937,
#  13941,
#  13955,
#  13978,
#  14003,
#  14014,
#  14068,
#  14106,
#  14145,
#  14192,
#  14213,
#  14236,
#  14240,
#  14241,
#  14242,
#  14246,
#  14248,
#  14250,
#  14251,
#  14252,
#  14253,
#  14254,
#  14256,
#  14258,
#  14259,
#  14260,
#  14261,
#  14262,
#  14263,
#  14265,
#  14267,
#  14268,
#  14269,
#  14270,
#  14271,
#  14272,
#  14273,
#  14274,
#  14278,
#  14279,
#  14280,
#  14281,
#  14282,
#  14283,
#  14284,
#  14286,
#  14287,
#  14289,
#  14291,
#  14294,
#  14295,
#  14296,
#  14297,
#  14299,
#  14301,
#  14305,
#  14391,
#  14430,
#  14433,
#  14434,
#  14438,
#  14439,
#  14448,
#  14474,
#  14478,
#  14479,
#  14482,
#  14484,
#  14491,
#  14495,
#  14551,
#  14596,
#  14599,
#  14605,
#  14639,
#  14654,
#  14663,
#  14692,
#  14710,
#  14712,
#  14749,
#  14779,
#  14791,
#  14792,
#  14810,
#  14819,
#  14822,
#  14835,
#  14845,
#  14846,
#  14847,
#  14848,
#  14849,
#  14850,
#  14851,
#  14852,
#  14853,
#  14854,
#  14856,
#  14858,
#  14859,
#  14861,
#  14863,
#  14879,
#  14880,
#  14911,
#  14920,
#  14956,
#  14964,
#  14970,
#  14988,
#  15047,
#  15066,
#  15109,
#  15136,
#  15137,
#  15152,
#  15194,
#  15253,
#  15314,
#  15332,
#  15342,
#  15347,
#  15349,
#  15352,
#  15355,
#  15361]

# %%
df = df.drop(labels=non_eng_book_index, axis=0)

# %%
df.shape
# Out:
# (14717, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   4.16        female
# 837                   3.82        female
# 838                   3.99          male
# 839                   4.05          male
# 840                   3.94          male
#
#                                          author_genres  author_id  \
# 0                                  historical-fiction,      74489
# 1                literature-fiction,mystery-thrillers,     706255
# 2                                             romance,    5618190
# 3                                      fiction,memoir,      37871
# 4                                 young-adult,fantasy,      36122
# ..                                                 ...        ...
# 836  literature-fiction,children-s-books,mystery-th...    1040250
# 837                                  children-s-books,      29182
# 838            literature-fiction,biographies-memoirs,       3075
# 839             literature-fiction,historical-fiction,      16204
# 840                                literature-fiction,      10039
#
#                author_name                           author_page_url  \
# 0      Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1          Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3            José Donoso\n             /author/show/37871.Jos_Donoso
# 4      Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# ..                     ...                                       ...
# 836            M.M. Kaye\n             /author/show/1040250.M_M_Kaye
# 837  Patricia MacLachlan\n    /author/show/29182.Patricia_MacLachlan
# 838          John Irving\n             /author/show/3075.John_Irving
# 839    Edward Rutherfurd\n      /author/show/16204.Edward_Rutherfurd
# 840          John Fowles\n            /author/show/10039.John_Fowles
#
#      author_rating_count  author_review_count             birthplace  \
# 0                  74399                 6268    United States\n
# 1                3726435               142704           Sweden\n
# 2                  76496                 7975      United States\n
# 3                   5522                  489            Chile\n
# 4                 291013                13453    United States\n
# ..                   ...                  ...                    ...
# 836                63288                 3509            India\n
# 837                99448                 7991    United States\n
# 838               875847                37287      United States\n
# 839               141650                 9991     United Kingdom\n
# 840               143385                 7647   United Kingdom\n
#
#      book_average_rating                                       book_fullurl  \
# 0                   4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                   4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                   3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                   4.14  https://www.goodreads.com/book/show/382975.The...
# 4                   4.01  https://www.goodreads.com/book/show/64207.Sorc...
# ..                   ...                                                ...
# 836                 4.21  https://www.goodreads.com/book/show/10222.The_...
# 837                 3.74  https://www.goodreads.com/book/show/106264.Sar...
# 838                 4.12  https://www.goodreads.com/book/show/4687.The_C...
# 839                 4.07   https://www.goodreads.com/book/show/92160.London
# 840                 3.86  https://www.goodreads.com/book/show/56034.The_...
#
#       book_id                                         book_title     genre_1  \
# 0      686717               \n      Murder on St. Mark's Place\n     Mystery
# 1     2429135          \n      The Girl with the Dragon Tattoo\n     Fiction
# 2    27833684                     \n      Tailored for Trouble\n     Romance
# 3      382975                \n      The Obscene Bird of Night\n     Fiction
# 4       64207  \n      Sorcery & Cecelia: or The Enchanted Ch...     Fantasy
# ..        ...                                                ...         ...
# 836     10222                        \n      The Far Pavilions\n  Historical
# 837    106264                    \n      Sarah, Plain and Tall\n  Historical
# 838      4687                    \n      The Cider House Rules\n     Fiction
# 839     92160                                   \n      London\n  Historical
# 840     56034            \n      The French Lieutenant's Woman\n     Fiction
#
#              genre_2  num_ratings  num_reviews pages      publish_date  score
# 0         Historical         5260          375   277              2000   3230
# 1            Mystery      2229163        65227   465       August 2005   3062
# 2       Contemporary         2151          391   354              2016   4585
# 3    Magical Realism         1844          173   438              1970   1533
# 4        Young Adult        17051         1890   326   April 15th 1988   2105
# ..               ...          ...          ...   ...               ...    ...
# 836          Fiction        37435         1183   958              1978  19694
# 837        Childrens        63635         2350    64              1985  20535
# 838       Historical       145206         3433   973     May 10th 1985  21279
# 839          Fiction        23602         1408  1152  January 1st 1997  21859
# 840         Classics        42711         1447   470              1969  24326
#
# [841 rows x 20 columns]

# %%
################################
###make sure average rate between 0-5
################################

# %%
df['author_average_rating'][0]<5.0
# Out:
# True

# %%
df['author_average_rating'][1682]
# Out:
# 5.0

# %%
rate_index_to_delete = []
for i in range(len(df['author_average_rating'])):
    if not (df['author_average_rating'][i] <= 5.0 and df['author_average_rating'][i] >= 0):
        rate_index_to_delete.append(i)
rate_index_to_delete
# Out:
# []

# %%
######################
##keep only the dates in years
######################

# %%
a = []
for i in range(len(df['publish_date'])):
    #for x in range(len(df['publish_date'][i])):
    a.append(df['publish_date'][i])
a
# Out:
# ['2000',
#  'August 2005',
#  '2016',
#  '1970',
#  'April 15th 1988',
#  'August 20th 2012',
#  '2008',
#  'January 1st 1993',
#  'April 1st 2007',
#  '2015',
#  '2013',
#  '2006',
#  '2010',
#  '1962',
#  'April 7th 2014',
#  'March 6th 2014',
#  '2014',
#  '2014',
#  'June 26th 2014',
#  'July 24th 2013',
#  '2014',
#  'June 19th 2014',
#  '2014',
#  'April 22nd 2014',
#  '2014',
#  '2014',
#  'September 29th 2014',
#  '2014',
#  'February 1st 2014',
#  'January 16th 2014',
#  'February 10th 2014',
#  'February 6th 2014',
#  'January 1st 2011',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  'August 29th 2014',
#  '2014',
#  'April 15th 2014',
#  'September 26th 2014',
#  '2014',
#  '2014',
#  '2014',
#  'April 17th 2014',
#  'January 17th 2014',
#  'April 27th 2014',
#  'August 31st 2014',
#  'February 23rd 2014',
#  'January 21st 2014',
#  'September 14th 2014',
#  'April 10th 2014',
#  'May 2014',
#  '2014',
#  '2014',
#  '2014',
#  'February 18th 2014',
#  '2014',
#  'January 29th 2014',
#  'January 1st 2014',
#  '2014',
#  'June 29th 2014',
#  'September 30th 2014',
#  'February 15th 2014',
#  'March 22nd 2014',
#  'February 27th 2014',
#  '2014',
#  'January 30th 2014',
#  'May 2nd 2014',
#  'September 12th 2014',
#  'June 15th 2014',
#  'July 7th 2014',
#  'March 9th 2014',
#  'January 1st 2010',
#  'November 1st 1987',
#  '2004',
#  'July 1st 1961',
#  '2010',
#  '1967',
#  '1952',
#  '1977',
#  '1949',
#  '1963',
#  '2006',
#  'January 1977',
#  'November 6th 2009',
#  'February 1995',
#  '2012',
#  '2014',
#  'May 1st 1982',
#  '1950',
#  'December 1974',
#  '1987',
#  'July 1957',
#  '1985',
#  '2014',
#  '1959',
#  '1955',
#  '1516',
#  '2011',
#  'October 1993',
#  'September 23rd 2002',
#  'May 1974',
#  '1925',
#  '2011',
#  '2002',
#  '1957',
#  '1992',
#  '1984',
#  'October 1959',
#  '1995',
#  '1921',
#  '2012',
#  '2006',
#  '1999',
#  'by',
#  'May 7th 1895',
#  '2012',
#  '2006',
#  'April 22nd 2003',
#  'April 5th 2005',
#  '2009',
#  '2007',
#  'February 1st 1997',
#  '2007',
#  'August 1938',
#  '2009',
#  '2009',
#  'January 28th 1813',
#  '2009',
#  '2006',
#  'September 30th 1868',
#  'July 10th 2002',
#  'September 2006',
#  '1943',
#  'January 1963',
#  'January 17th 1996',
#  '1989',
#  '1995',
#  '2007',
#  'August 23rd 2005',
#  '2006',
#  'August 8th 2000',
#  '1997',
#  'October 20th 1955',
#  '2009',
#  '2007',
#  'August 1st 2009',
#  'March 2nd 2006',
#  'October 1989',
#  '2001',
#  '2009',
#  'June 23rd 2005',
#  '2005',
#  'April 28th 2009',
#  'September 1st 2006',
#  '2008',
#  'June 1st 2012',
#  'February 6th 2001',
#  'March 17th 1995',
#  '2009',
#  'January 1st 2013',
#  '2011',
#  '2005',
#  '2010',
#  '2008',
#  '2012',
#  '2011',
#  '2012',
#  'January 1st 2004',
#  '2001',
#  '1995',
#  '2011',
#  'July 1989',
#  '2009',
#  nan,
#  '1989',
#  '2010',
#  '2011',
#  '2011',
#  '2001',
#  'September 1997',
#  'December 17th 2012',
#  'September 4th 2011',
#  '1999',
#  '2009',
#  'June 30th 1936',
#  'April 1st 2011',
#  'May 25th 2012',
#  'April 3rd 2012',
#  '2011',
#  '2013',
#  '2013',
#  'January 1st 2013',
#  '2013',
#  'February 28th 2013',
#  'January 27th 2013',
#  '2013',
#  'March 1st 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  'June 6th 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  'February 1st 2013',
#  'October 26th 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  'April 14th 2013',
#  '2013',
#  'March 19th 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  'January 1st 2013',
#  '2013',
#  'September 5th 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  'January 1st 2013',
#  'August 15th 2013',
#  'March 1st 2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  'June 1st 2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2013',
#  '2014',
#  'May 24th 2012',
#  '2009',
#  'November 6th 2013',
#  '2016',
#  '2016',
#  '2012',
#  '2010',
#  '2009',
#  '2010',
#  'May 2nd 1955',
#  'June 23rd 2001',
#  'December 1st 2009',
#  '2009',
#  '2010',
#  'March 17th 2011',
#  '2011',
#  '2007',
#  '2009',
#  '2015',
#  '2009',
#  '2010',
#  '2005',
#  '2010',
#  '2011',
#  '1997',
#  '2009',
#  '2010',
#  'February 1st 2011',
#  '1989',
#  '1961',
#  '2004',
#  '2006',
#  'January 1st 1987',
#  '1995',
#  '1975',
#  '1991',
#  'March 6th 2007',
#  '1954',
#  '1992',
#  '2011',
#  '2007',
#  '1986',
#  '2002',
#  'September 7th 2010',
#  'January 1st 2003',
#  'March 10th 1983',
#  'October 13th 2011',
#  '1980',
#  '2006',
#  'May 22nd 2009',
#  '2000',
#  '2008',
#  'May 5th 1990',
#  '1992',
#  '1988',
#  '1989',
#  '2005',
#  '2003',
#  'April 1st 2009',
#  '2007',
#  '2010',
#  'September 1st 1994',
#  '1981',
#  '2005',
#  '1980',
#  'August 26th 2008',
#  '2009',
#  'January 31st 2006',
#  '2005',
#  '1992',
#  '1998',
#  'January 1st 2005',
#  '1998',
#  'January 1st 1998',
#  'June 26th 1986',
#  'September 1982',
#  'September 1st 1995',
#  '2009',
#  '2004',
#  '2009',
#  '2006',
#  'September 1992',
#  nan,
#  'April 1st 2004',
#  '2007',
#  '2006',
#  '1872',
#  'September 1st 2003',
#  '2001',
#  'May 2004',
#  '1897',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  'January 1st 2008',
#  '2008',
#  '2008',
#  'June 25th 2005',
#  '2008',
#  '2008',
#  '2008',
#  'May 1st 2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  'April 28th 2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  'January 1st 2008',
#  '2002',
#  'January 1st 2008',
#  '2008',
#  '2008',
#  '2008',
#  'November 11th 2007',
#  '2008',
#  '2008',
#  'January 1st 2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  'October 16th 2008',
#  'January 1st 2008',
#  'by',
#  '2008',
#  '2008',
#  '2008',
#  'by',
#  '2012',
#  '2011',
#  '2010',
#  'December 2012',
#  '2012',
#  '2012',
#  '2012',
#  '2010',
#  '2006',
#  '2010',
#  '2015',
#  'March 8th 2011',
#  '2011',
#  '2012',
#  '2011',
#  '2011',
#  '2012',
#  'April 29th 2011',
#  'August 20th 2012',
#  '2010',
#  'July 27th 2011',
#  '2005',
#  'March 2005',
#  'May 22nd 2007',
#  'January 13th 2011',
#  'October 12th 2012',
#  'May 12th 2005',
#  'April 20th 2011',
#  '2012',
#  '2011',
#  '2010',
#  '2010',
#  'June 13th 2011',
#  'December 22nd 2011',
#  'December 22nd 2010',
#  'March 14th 2011',
#  '2012',
#  '2010',
#  'November 13th 2012',
#  '2012',
#  '2007',
#  '1998',
#  '2015',
#  'November 2001',
#  '2013',
#  '1999',
#  '1983',
#  '1981',
#  '2006',
#  '2002',
#  '1981',
#  'November 25th 2005',
#  'September 20th 2007',
#  'October 27th 2004',
#  '2006',
#  '1989',
#  '2004',
#  'November 7th 2007',
#  '2007',
#  'June 15th 2009',
#  'October 2003',
#  '1989',
#  '2009',
#  '2007',
#  '1978',
#  '2002',
#  '2011',
#  'July 14th 1960',
#  '1996',
#  '2011',
#  '2000',
#  '1993',
#  'August 1996',
#  '2009',
#  'September 29th 2008',
#  '1995',
#  'September 1st 2006',
#  '2006',
#  'March 1998',
#  'January 1st 1991',
#  'June 8th 2006',
#  'January 1st 1986',
#  'January 1st 2002',
#  'November 12th 2013',
#  'March 21st 2014',
#  'January 1st 2007',
#  '1968',
#  '2006',
#  '2017',
#  'December 21st 1982',
#  '1997',
#  '1998',
#  '2014',
#  '2004',
#  'January 1st 1970',
#  '1996',
#  '1975',
#  '1938',
#  '1905',
#  'March 1976',
#  '2002',
#  '1954',
#  '1999',
#  'March 12th 1982',
#  '2003',
#  'October 1st 1988',
#  '2000',
#  '1996',
#  'January 15th 1990',
#  'September 1st 2004',
#  'July 1st 2003',
#  '1986',
#  'April 1st 2005',
#  '1983',
#  'January 2002',
#  '1979',
#  'March 12th 1964',
#  'January 1st 2004',
#  'May 17th 1900',
#  'March 27th 2007',
#  '1973',
#  '2007',
#  'January 9th 2004',
#  'October 21st 1977',
#  '2009',
#  'May 22nd 2007',
#  'by',
#  '1986',
#  '1962',
#  '2003',
#  'March 15th 2005',
#  '2018',
#  '2012',
#  '2009',
#  '2012',
#  'July 1st 2013',
#  '2011',
#  'June 1st 2011',
#  'July 15th 2009',
#  '2011',
#  'January 1st 2002',
#  '1999',
#  'September 28th 2004',
#  '2008',
#  'March 1st 2005',
#  'September 27th 2005',
#  '2013',
#  'May 26th 2009',
#  '2007',
#  'August 20th 2009',
#  '2017',
#  '1989',
#  '2008',
#  'January 1st 2009',
#  '2014',
#  '2007',
#  'May 1st 2009',
#  '2013',
#  '2014',
#  'October 1st 2008',
#  'August 27th 2001',
#  '2016',
#  '2012',
#  '2017',
#  '2012',
#  '2007',
#  '2011',
#  '1982',
#  '2012',
#  '2013',
#  'May 2nd 2007',
#  '1983',
#  '2011',
#  '1997',
#  'February 15th 2000',
#  '1990',
#  '2011',
#  '1988',
#  'October 13th 1988',
#  '1962',
#  '1967',
#  '2011',
#  '2009',
#  'January 1st 1989',
#  '1988',
#  '1983',
#  '1997',
#  '1927',
#  'March 3rd 2011',
#  '1982',
#  'October 19th 2004',
#  '1966',
#  '1998',
#  'May 17th 2005',
#  '1974',
#  'April 17th 2008',
#  '1959',
#  'January 1st 2014',
#  '2012',
#  'April 1976',
#  '1972',
#  '1987',
#  '2010',
#  'June 2nd 1979',
#  'August 1981',
#  'April 1st 2013',
#  '2007',
#  '1983',
#  'September 11th 2001',
#  '2011',
#  'April 16th 2002',
#  '2011',
#  '1944',
#  '2011',
#  '1967',
#  '1989',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  'March 27th 2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2016',
#  '2016',
#  'October 29th 2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  'January 1st 1994',
#  '1962',
#  'April 1st 1891',
#  'November 1859',
#  '1952',
#  '-720',
#  'July 10th 2008',
#  '1978',
#  '1937',
#  '1970',
#  'February 16th 2006',
#  'September 24th 1998',
#  '1856',
#  'April 14th 1939',
#  '1876',
#  '1899',
#  'November 8th 2001',
#  '1985',
#  '1953',
#  'June 1st 1991',
#  '1958',
#  '1903',
#  '1962',
#  'September 1st 1952',
#  '1390',
#  'May 1st 2007',
#  'July 9th 1995',
#  'November 1972',
#  '1866',
#  '1942',
#  'January 5th 2006',
#  '1989',
#  'May 26th 2006',
#  'July 3rd 2002',
#  '1988',
#  'January 1st 1818',
#  'March 1966',
#  'December 1847',
#  '2009',
#  'July 31st 2003',
#  'March 16th 1850',
#  'April 1943',
#  '1606',
#  'September 1st 2005',
#  'August 17th 1945',
#  '1958',
#  'July 16th 1951',
#  'October 16th 1847',
#  'September 17th 1954',
#  '1947',
#  '1967',
#  '1925',
#  'July 11th 1960',
#  'November 26th 1859',
#  '1994',
#  '2001',
#  '2004',
#  'January 1st 2006',
#  '2006',
#  '2005',
#  'January 1st 2011',
#  '1981',
#  '1992',
#  '1961',
#  '1993',
#  '1998',
#  '2008',
#  'April 13th 2014',
#  '2010',
#  '1988',
#  '2008',
#  'January 1st 2004',
#  '1990',
#  '2015',
#  'September 15th 1994',
#  'January 1st 1993',
#  '1990',
#  'August 29th 1996',
#  '2007',
#  '2010',
#  '2000',
#  '1980',
#  'September 2nd 2010',
#  'October 10th 2004',
#  '1991',
#  '2009',
#  'December 1st 1994',
#  '2006',
#  'January 1st 2005',
#  '2007',
#  '2002',
#  '2003',
#  'November 21st 2003',
#  '1989',
#  '1990',
#  'by',
#  '1997',
#  '2009',
#  '1985',
#  '1949',
#  '2006',
#  'by',
#  '2005',
#  'January 1st 1998',
#  '2014',
#  '1988',
#  '1976',
#  '1971',
#  '1930',
#  '2006',
#  '2006',
#  'May 1st 2001',
#  'January 17th 2001',
#  'April 1st 2000',
#  '2000',
#  '2001',
#  'by',
#  '2009',
#  'May 17th 2005',
#  'September 2001',
#  'January 2004',
#  '2005',
#  'September 19th 2000',
#  '2003',
#  'May 22nd 2001',
#  'September 4th 2002',
#  '1935',
#  '1980',
#  '2002',
#  '1965',
#  '2004',
#  '1984',
#  '1978',
#  '1985',
#  'May 10th 1985',
#  'January 1st 1997',
#  '1969',
#  '1944',
#  '1982',
#  '1990',
#  '1966',
#  '2007',
#  '2003',
#  'September 8th 2004',
#  '1819',
#  'April 30th 2009',
#  'October 21st 2003',
#  '1958',
#  '1987',
#  '2014',
#  '1996',
#  '1905',
#  '1958',
#  '1954',
#  'September 1992',
#  '1934',
#  '1844',
#  'January 1st 1997',
#  '1985',
#  '1997',
#  'January 16th 1605',
#  'March 20th 1852',
#  'January 1st 1929',
#  '1867',
#  'September 3rd 1947',
#  '1955',
#  '1990',
#  'April 19th 1963',
#  'June 20th 1890',
#  '1872',
#  '1964',
#  '2007',
#  'October 9th 2001',
#  '1967',
#  '1945',
#  'September 11th 2001',
#  '1961',
#  'June 1908',
#  'August 1st 2003',
#  '2007',
#  '1998',
#  '1973',
#  'January 1974',
#  '1979',
#  'October 1976',
#  '1973',
#  '1978',
#  '1972',
#  'June 28th 1973',
#  'October 30th 1979',
#  '1977',
#  '1971',
#  '1971',
#  '1979',
#  '1973',
#  '1979',
#  '1972',
#  '1970',
#  '1978',
#  '1979',
#  'January 1st 1979',
#  'August 26th 1970',
#  'February 28th 1973',
#  '1976',
#  'August 6th 1971',
#  '1974',
#  '1978',
#  '1974',
#  '1975',
#  '1973',
#  '1974',
#  '1974',
#  '1974',
#  'June 1971',
#  'April 1970',
#  '1971',
#  '2012',
#  nan,
#  '2012',
#  '2012',
#  'February 17th 2011',
#  '2012',
#  'January 1st 2012',
#  '2012',
#  'July 1st 2011',
#  'August 28th 2011',
#  'by',
#  'January 1st 2012',
#  '2011',
#  '2012',
#  '2012',
#  'November 8th 2012',
#  '2012',
#  'July 25th 2012',
#  '2012',
#  'May 16th 2012',
#  '2012',
#  'August 28th 2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  'May 1st 2012',
#  '2012',
#  '2012',
#  'August 10th 2012',
#  '2012',
#  '2012',
#  '2012',
#  'September 22nd 2012',
#  'September 1st 2012',
#  '2012',
#  '2012',
#  'September 9th 2005',
#  'November 7th 1990',
#  '2015',
#  'July 31st 2014',
#  '1960',
#  '1976',
#  '2011',
#  nan,
#  '1995',
#  '1959',
#  '1953',
#  'by',
#  'November 8th 2003',
#  '1998',
#  '1991',
#  '1948',
#  '1671',
#  '1921',
#  nan,
#  '2003',
#  'January 1st 2004',
#  '1961',
#  '1943',
#  '1927',
#  'January 1st 2014',
#  'December 17th 2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  'January 1st 2012',
#  '2013',
#  'January 25th 2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  ...]

# %%
a[0][-4:]
# Out:
# '2000'

# %%
only_year = []
for x in a:
    #b = x[-4:]
    only_year.append(str(x)[-4:])
only_year
# Out:
# ['2000',
#  '2005',
#  '2016',
#  '1970',
#  '1988',
#  '2012',
#  '2008',
#  '1993',
#  '2007',
#  '2015',
#  '2013',
#  '2006',
#  '2010',
#  '1962',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2011',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2010',
#  '1987',
#  '2004',
#  '1961',
#  '2010',
#  '1967',
#  '1952',
#  '1977',
#  '1949',
#  '1963',
#  '2006',
#  '1977',
#  '2009',
#  '1995',
#  '2012',
#  '2014',
#  '1982',
#  '1950',
#  '1974',
#  '1987',
#  '1957',
#  '1985',
#  '2014',
#  '1959',
#  '1955',
#  '1516',
#  '2011',
#  '1993',
#  '2002',
#  '1974',
#  '1925',
#  '2011',
#  '2002',
#  '1957',
#  '1992',
#  '1984',
#  '1959',
#  '1995',
#  '1921',
#  '2012',
#  '2006',
#  '1999',
#  'by',
#  '1895',
#  '2012',
#  '2006',
#  '2003',
#  '2005',
#  '2009',
#  '2007',
#  '1997',
#  '2007',
#  '1938',
#  '2009',
#  '2009',
#  '1813',
#  '2009',
#  '2006',
#  '1868',
#  '2002',
#  '2006',
#  '1943',
#  '1963',
#  '1996',
#  '1989',
#  '1995',
#  '2007',
#  '2005',
#  '2006',
#  '2000',
#  '1997',
#  '1955',
#  '2009',
#  '2007',
#  '2009',
#  '2006',
#  '1989',
#  '2001',
#  '2009',
#  '2005',
#  '2005',
#  '2009',
#  '2006',
#  '2008',
#  '2012',
#  '2001',
#  '1995',
#  '2009',
#  '2013',
#  '2011',
#  '2005',
#  '2010',
#  '2008',
#  '2012',
#  '2011',
#  '2012',
#  '2004',
#  '2001',
#  '1995',
#  '2011',
#  '1989',
#  '2009',
#  'nan',
#  '1989',
#  '2010',
#  '2011',
#  '2011',
#  '2001',
#  '1997',
#  '2012',
#  '2011',
#  '1999',
#  '2009',
#  '1936',
#  '2011',
#  '2012',
#  '2012',
#  '2011',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2013',
#  '2014',
#  '2012',
#  '2009',
#  '2013',
#  '2016',
#  '2016',
#  '2012',
#  '2010',
#  '2009',
#  '2010',
#  '1955',
#  '2001',
#  '2009',
#  '2009',
#  '2010',
#  '2011',
#  '2011',
#  '2007',
#  '2009',
#  '2015',
#  '2009',
#  '2010',
#  '2005',
#  '2010',
#  '2011',
#  '1997',
#  '2009',
#  '2010',
#  '2011',
#  '1989',
#  '1961',
#  '2004',
#  '2006',
#  '1987',
#  '1995',
#  '1975',
#  '1991',
#  '2007',
#  '1954',
#  '1992',
#  '2011',
#  '2007',
#  '1986',
#  '2002',
#  '2010',
#  '2003',
#  '1983',
#  '2011',
#  '1980',
#  '2006',
#  '2009',
#  '2000',
#  '2008',
#  '1990',
#  '1992',
#  '1988',
#  '1989',
#  '2005',
#  '2003',
#  '2009',
#  '2007',
#  '2010',
#  '1994',
#  '1981',
#  '2005',
#  '1980',
#  '2008',
#  '2009',
#  '2006',
#  '2005',
#  '1992',
#  '1998',
#  '2005',
#  '1998',
#  '1998',
#  '1986',
#  '1982',
#  '1995',
#  '2009',
#  '2004',
#  '2009',
#  '2006',
#  '1992',
#  'nan',
#  '2004',
#  '2007',
#  '2006',
#  '1872',
#  '2003',
#  '2001',
#  '2004',
#  '1897',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2005',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2002',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  'by',
#  '2008',
#  '2008',
#  '2008',
#  'by',
#  '2012',
#  '2011',
#  '2010',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2010',
#  '2006',
#  '2010',
#  '2015',
#  '2011',
#  '2011',
#  '2012',
#  '2011',
#  '2011',
#  '2012',
#  '2011',
#  '2012',
#  '2010',
#  '2011',
#  '2005',
#  '2005',
#  '2007',
#  '2011',
#  '2012',
#  '2005',
#  '2011',
#  '2012',
#  '2011',
#  '2010',
#  '2010',
#  '2011',
#  '2011',
#  '2010',
#  '2011',
#  '2012',
#  '2010',
#  '2012',
#  '2012',
#  '2007',
#  '1998',
#  '2015',
#  '2001',
#  '2013',
#  '1999',
#  '1983',
#  '1981',
#  '2006',
#  '2002',
#  '1981',
#  '2005',
#  '2007',
#  '2004',
#  '2006',
#  '1989',
#  '2004',
#  '2007',
#  '2007',
#  '2009',
#  '2003',
#  '1989',
#  '2009',
#  '2007',
#  '1978',
#  '2002',
#  '2011',
#  '1960',
#  '1996',
#  '2011',
#  '2000',
#  '1993',
#  '1996',
#  '2009',
#  '2008',
#  '1995',
#  '2006',
#  '2006',
#  '1998',
#  '1991',
#  '2006',
#  '1986',
#  '2002',
#  '2013',
#  '2014',
#  '2007',
#  '1968',
#  '2006',
#  '2017',
#  '1982',
#  '1997',
#  '1998',
#  '2014',
#  '2004',
#  '1970',
#  '1996',
#  '1975',
#  '1938',
#  '1905',
#  '1976',
#  '2002',
#  '1954',
#  '1999',
#  '1982',
#  '2003',
#  '1988',
#  '2000',
#  '1996',
#  '1990',
#  '2004',
#  '2003',
#  '1986',
#  '2005',
#  '1983',
#  '2002',
#  '1979',
#  '1964',
#  '2004',
#  '1900',
#  '2007',
#  '1973',
#  '2007',
#  '2004',
#  '1977',
#  '2009',
#  '2007',
#  'by',
#  '1986',
#  '1962',
#  '2003',
#  '2005',
#  '2018',
#  '2012',
#  '2009',
#  '2012',
#  '2013',
#  '2011',
#  '2011',
#  '2009',
#  '2011',
#  '2002',
#  '1999',
#  '2004',
#  '2008',
#  '2005',
#  '2005',
#  '2013',
#  '2009',
#  '2007',
#  '2009',
#  '2017',
#  '1989',
#  '2008',
#  '2009',
#  '2014',
#  '2007',
#  '2009',
#  '2013',
#  '2014',
#  '2008',
#  '2001',
#  '2016',
#  '2012',
#  '2017',
#  '2012',
#  '2007',
#  '2011',
#  '1982',
#  '2012',
#  '2013',
#  '2007',
#  '1983',
#  '2011',
#  '1997',
#  '2000',
#  '1990',
#  '2011',
#  '1988',
#  '1988',
#  '1962',
#  '1967',
#  '2011',
#  '2009',
#  '1989',
#  '1988',
#  '1983',
#  '1997',
#  '1927',
#  '2011',
#  '1982',
#  '2004',
#  '1966',
#  '1998',
#  '2005',
#  '1974',
#  '2008',
#  '1959',
#  '2014',
#  '2012',
#  '1976',
#  '1972',
#  '1987',
#  '2010',
#  '1979',
#  '1981',
#  '2013',
#  '2007',
#  '1983',
#  '2001',
#  '2011',
#  '2002',
#  '2011',
#  '1944',
#  '2011',
#  '1967',
#  '1989',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '1994',
#  '1962',
#  '1891',
#  '1859',
#  '1952',
#  '-720',
#  '2008',
#  '1978',
#  '1937',
#  '1970',
#  '2006',
#  '1998',
#  '1856',
#  '1939',
#  '1876',
#  '1899',
#  '2001',
#  '1985',
#  '1953',
#  '1991',
#  '1958',
#  '1903',
#  '1962',
#  '1952',
#  '1390',
#  '2007',
#  '1995',
#  '1972',
#  '1866',
#  '1942',
#  '2006',
#  '1989',
#  '2006',
#  '2002',
#  '1988',
#  '1818',
#  '1966',
#  '1847',
#  '2009',
#  '2003',
#  '1850',
#  '1943',
#  '1606',
#  '2005',
#  '1945',
#  '1958',
#  '1951',
#  '1847',
#  '1954',
#  '1947',
#  '1967',
#  '1925',
#  '1960',
#  '1859',
#  '1994',
#  '2001',
#  '2004',
#  '2006',
#  '2006',
#  '2005',
#  '2011',
#  '1981',
#  '1992',
#  '1961',
#  '1993',
#  '1998',
#  '2008',
#  '2014',
#  '2010',
#  '1988',
#  '2008',
#  '2004',
#  '1990',
#  '2015',
#  '1994',
#  '1993',
#  '1990',
#  '1996',
#  '2007',
#  '2010',
#  '2000',
#  '1980',
#  '2010',
#  '2004',
#  '1991',
#  '2009',
#  '1994',
#  '2006',
#  '2005',
#  '2007',
#  '2002',
#  '2003',
#  '2003',
#  '1989',
#  '1990',
#  'by',
#  '1997',
#  '2009',
#  '1985',
#  '1949',
#  '2006',
#  'by',
#  '2005',
#  '1998',
#  '2014',
#  '1988',
#  '1976',
#  '1971',
#  '1930',
#  '2006',
#  '2006',
#  '2001',
#  '2001',
#  '2000',
#  '2000',
#  '2001',
#  'by',
#  '2009',
#  '2005',
#  '2001',
#  '2004',
#  '2005',
#  '2000',
#  '2003',
#  '2001',
#  '2002',
#  '1935',
#  '1980',
#  '2002',
#  '1965',
#  '2004',
#  '1984',
#  '1978',
#  '1985',
#  '1985',
#  '1997',
#  '1969',
#  '1944',
#  '1982',
#  '1990',
#  '1966',
#  '2007',
#  '2003',
#  '2004',
#  '1819',
#  '2009',
#  '2003',
#  '1958',
#  '1987',
#  '2014',
#  '1996',
#  '1905',
#  '1958',
#  '1954',
#  '1992',
#  '1934',
#  '1844',
#  '1997',
#  '1985',
#  '1997',
#  '1605',
#  '1852',
#  '1929',
#  '1867',
#  '1947',
#  '1955',
#  '1990',
#  '1963',
#  '1890',
#  '1872',
#  '1964',
#  '2007',
#  '2001',
#  '1967',
#  '1945',
#  '2001',
#  '1961',
#  '1908',
#  '2003',
#  '2007',
#  '1998',
#  '1973',
#  '1974',
#  '1979',
#  '1976',
#  '1973',
#  '1978',
#  '1972',
#  '1973',
#  '1979',
#  '1977',
#  '1971',
#  '1971',
#  '1979',
#  '1973',
#  '1979',
#  '1972',
#  '1970',
#  '1978',
#  '1979',
#  '1979',
#  '1970',
#  '1973',
#  '1976',
#  '1971',
#  '1974',
#  '1978',
#  '1974',
#  '1975',
#  '1973',
#  '1974',
#  '1974',
#  '1974',
#  '1971',
#  '1970',
#  '1971',
#  '2012',
#  'nan',
#  '2012',
#  '2012',
#  '2011',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  'by',
#  '2012',
#  '2011',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2005',
#  '1990',
#  '2015',
#  '2014',
#  '1960',
#  '1976',
#  '2011',
#  'nan',
#  '1995',
#  '1959',
#  '1953',
#  'by',
#  '2003',
#  '1998',
#  '1991',
#  '1948',
#  '1671',
#  '1921',
#  'nan',
#  '2003',
#  '2004',
#  '1961',
#  '1943',
#  '1927',
#  '2014',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2012',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  ...]

# %%
#drop original column
df.drop(['publish_date'], axis=1)
# Out:
#        author_average_rating author_gender  \
# 0                       4.01        female
# 1                       4.15          male
# 2                       4.00        female
# 3                       3.88          male
# 4                       4.10        female
# ...                      ...           ...
# 14712                   4.08        female
# 14713                   4.09        female
# 14714                   3.94        female
# 14715                   4.00        female
# 14716                   4.20        female
#
#                                author_genres  author_id  \
# 0                        historical-fiction,      74489
# 1      literature-fiction,mystery-thrillers,     706255
# 2                                   romance,    5618190
# 3                            fiction,memoir,      37871
# 4                       young-adult,fantasy,      36122
# ...                                      ...        ...
# 14712                            paranormal,   12020546
# 14713                               romance,    8386732
# 14714                      humor-and-comedy,     108007
# 14715                               romance,    6543639
# 14716                            paranormal,    5246010
#
#                  author_name                           author_page_url  \
# 0        Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1            Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2      Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3              José Donoso\n             /author/show/37871.Jos_Donoso
# 4        Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# ...                      ...                                       ...
# 14712          S.D. Wasley\n          /author/show/12020546.S_D_Wasley
# 14713         Victoria Zak\n         /author/show/8386732.Victoria_Zak
# 14714       Dakota Cassidy\n        /author/show/108007.Dakota_Cassidy
# 14715      Krystal Shannan\n      /author/show/6543639.Krystal_Shannan
# 14716          Bryce Evans\n          /author/show/5246010.Bryce_Evans
#
#        author_rating_count  author_review_count            birthplace  \
# 0                    74399                 6268   United States\n
# 1                  3726435               142704          Sweden\n
# 2                    76496                 7975     United States\n
# 3                     5522                  489           Chile\n
# 4                   291013                13453   United States\n
# ...                    ...                  ...                   ...
# 14712                  569                  165       Australia\n
# 14713                 2835                  449                  \n
# 14714                52944                 4558                  \n
# 14715                15626                 3530     United States\n
# 14716                 4689                  828                  \n
#
#        book_average_rating                                       book_fullurl  \
# 0                     4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                     4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                     3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                     4.14  https://www.goodreads.com/book/show/382975.The...
# 4                     4.01  https://www.goodreads.com/book/show/64207.Sorc...
# ...                    ...                                                ...
# 14712                 4.05  https://www.goodreads.com/book/show/24474924-t...
# 14713                 4.22  https://www.goodreads.com/book/show/23552511-h...
# 14714                 3.82  https://www.goodreads.com/book/show/24614174-g...
# 14715                 3.73  https://www.goodreads.com/book/show/35892811-m...
# 14716                 3.89  https://www.goodreads.com/book/show/17187320-t...
#
#         book_id                                         book_title  \
# 0        686717               \n      Murder on St. Mark's Place\n
# 1       2429135          \n      The Girl with the Dragon Tattoo\n
# 2      27833684                     \n      Tailored for Trouble\n
# 3        382975                \n      The Obscene Bird of Night\n
# 4         64207  \n      Sorcery & Cecelia: or The Enchanted Ch...
# ...         ...                                                ...
# 14712  24474924                              \n      The Seventh\n
# 14713  23552511                           \n      Highland Storm\n
# 14714  24614174                         \n      Gotta Have Faith\n
# 14715  35892811                        \n      My Viking Vampire\n
# 14716  17187320                              \n      The Trinity\n
#
#            genre_1          genre_2  num_ratings  num_reviews pages  score
# 0          Mystery       Historical         5260          375   277   3230
# 1          Fiction          Mystery      2229163        65227   465   3062
# 2          Romance     Contemporary         2151          391   354   4585
# 3          Fiction  Magical Realism         1844          173   438   1533
# 4          Fantasy      Young Adult        17051         1890   326   2105
# ...            ...              ...          ...          ...   ...    ...
# 14712  Young Adult          Fantasy          155           35   262   1000
# 14713      Romance          Romance          319           44   232   1146
# 14714      Fantasy          Romance          430           33    72   1215
# 14715      Fantasy       Paranormal         2698          375   237   1679
# 14716      Fantasy       Paranormal          356           38   222   1897
#
# [14717 rows x 19 columns]

# %%
#add new columns with only years
df['publish_date'] = only_year
df.head(1683)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 1678                   4.05        female
# 1679                   3.93        female
# 1680                   3.60        female
# 1681                   3.79          male
# 1682                   5.00          male
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# 4                      young-adult,fantasy,      36122    Patricia C. Wrede\n
# ...                                     ...        ...                    ...
# 1678                           young-adult,   14358948   Tricia Levenseller\n
# 1679                       science-fiction,    4615776       Meagan Spooner\n
# 1680                           young-adult,   13414088         S. Jae-Jones\n
# 1681                           young-adult,    8196241           Jen  Klein\n
# 1682                                 drama,   17120246         Fatih Turgut\n
#
#                                author_page_url  author_rating_count  \
# 0         /author/show/74489.Victoria_Thompson                74399
# 1            /author/show/706255.Stieg_Larsson              3726435
# 2     /author/show/5618190.Mimi_Jean_Pamfiloff                76496
# 3                /author/show/37871.Jos_Donoso                 5522
# 4          /author/show/36122.Patricia_C_Wrede               291013
# ...                                        ...                  ...
# 1678  /author/show/14358948.Tricia_Levenseller                30776
# 1679       /author/show/4615776.Meagan_Spooner               111628
# 1680         /author/show/13414088.S_Jae_Jones                25622
# 1681            /author/show/8196241.Jen_Klein                 5185
# 1682        /author/show/17120246.Fatih_Turgut                   21
#
#       author_review_count                birthplace  book_average_rating  \
# 0                    6268       United States\n                     4.02
# 1                  142704              Sweden\n                     4.13
# 2                    7975         United States\n                   3.99
# 3                     489               Chile\n                     4.14
# 4                   13453       United States\n                     4.01
# ...                   ...                       ...                  ...
# 1678                 5462                      \n                   3.99
# 1679                17914         United States\n                   3.92
# 1680                 5582         United States\n                   3.58
# 1681                  873  \n   United States\n                     3.67
# 1682                    0         \n  Australia\n                   5.00
#
#                                            book_fullurl   book_id  \
# 0     https://www.goodreads.com/book/show/686717.Mur...    686717
# 1     https://www.goodreads.com/book/show/2429135.Th...   2429135
# 2     https://www.goodreads.com/book/show/27833684-t...  27833684
# 3     https://www.goodreads.com/book/show/382975.The...    382975
# 4     https://www.goodreads.com/book/show/64207.Sorc...     64207
# ...                                                 ...       ...
# 1678  https://www.goodreads.com/book/show/33643994-d...  33643994
# 1679  https://www.goodreads.com/book/show/24485589-h...  24485589
# 1680  https://www.goodreads.com/book/show/24763621-w...  24763621
# 1681  https://www.goodreads.com/book/show/39396874-h...  39396874
# 1682  https://www.goodreads.com/book/show/36111357-s...  36111357
#
#                                              book_title       genre_1  \
# 0                  \n      Murder on St. Mark's Place\n       Mystery
# 1             \n      The Girl with the Dragon Tattoo\n       Fiction
# 2                        \n      Tailored for Trouble\n       Romance
# 3                   \n      The Obscene Bird of Night\n       Fiction
# 4     \n      Sorcery & Cecelia: or The Enchanted Ch...       Fantasy
# ...                                                 ...           ...
# 1678              \n      Daughter of the Pirate King\n       Fantasy
# 1679                                   \n      Hunted\n       Fantasy
# 1680                               \n      Wintersong\n       Fantasy
# 1681                 \n      Hearts Made for Breaking\n  Contemporary
# 1682                               \n      Sandcastle\n       Fantasy
#
#               genre_2  num_ratings  num_reviews pages publish_date  score
# 0          Historical         5260          375   277         2000   3230
# 1             Mystery      2229163        65227   465         2005   3062
# 2        Contemporary         2151          391   354         2016   4585
# 3     Magical Realism         1844          173   438         1970   1533
# 4         Young Adult        17051         1890   326         1988   2105
# ...               ...          ...          ...   ...          ...    ...
# 1678      Young Adult        21462         3824   311         2017  22065
# 1679      Young Adult        18140         3572   384         2017  34860
# 1680      Young Adult        21141         4440   436         2017  37971
# 1681      Young Adult           12            2   320         30th    456
# 1682          Novella            5            0   199         20th    472
#
# [1683 rows x 20 columns]

# %%
# delete non_int dates

# %%
df['publish_date'][1]. isdecimal()
# Out:
# True

# %%
df['publish_date'][1197]
# Out:
# '4th'

# %%
non_int_date_index = []
for i in range(len(df['publish_date'])):
    if df['publish_date'][i]. isdecimal() == False:
            non_int_date_index.append(i)
            #non_int_date_index.append(df['publish_date'][i])
non_int_date_index
# Out:
# [115,
#  175,
#  386,
#  443,
#  447,
#  574,
#  709,
#  799,
#  805,
#  820,
#  921,
#  930,
#  964,
#  968,
#  975,
#  1051,
#  1098,
#  1162,
#  1184,
#  1185,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1195,
#  1196,
#  1197,
#  1199,
#  1200,
#  1201,
#  1202,
#  1206,
#  1218,
#  1337,
#  1339,
#  1480,
#  1485,
#  1539,
#  1681,
#  1682,
#  1683,
#  1684,
#  1685,
#  1719,
#  1824,
#  1835,
#  1841,
#  1864,
#  1906,
#  1920,
#  1996,
#  2008,
#  2095,
#  2100,
#  2101,
#  2110,
#  2117,
#  2119,
#  2143,
#  2167,
#  2197,
#  2217,
#  2300,
#  2312,
#  2329,
#  2379,
#  2632,
#  2648,
#  2724,
#  2772,
#  2773,
#  2853,
#  2865,
#  2888,
#  2989,
#  3033,
#  3058,
#  3101,
#  3186,
#  3190,
#  3215,
#  3234,
#  3258,
#  3266,
#  3270,
#  3300,
#  3337,
#  3410,
#  3461,
#  3547,
#  3606,
#  3625,
#  3646,
#  3842,
#  3886,
#  3946,
#  3975,
#  3983,
#  4035,
#  4118,
#  4146,
#  4159,
#  4240,
#  4356,
#  4481,
#  4528,
#  4593,
#  4610,
#  4612,
#  4726,
#  4744,
#  4840,
#  4846,
#  4898,
#  4904,
#  4922,
#  4929,
#  4944,
#  4946,
#  4978,
#  5097,
#  5147,
#  5149,
#  5151,
#  5155,
#  5161,
#  5162,
#  5164,
#  5167,
#  5172,
#  5173,
#  5174,
#  5176,
#  5178,
#  5182,
#  5184,
#  5187,
#  5203,
#  5205,
#  5267,
#  5274,
#  5312,
#  5377,
#  5470,
#  5483,
#  5522,
#  5530,
#  5538,
#  5546,
#  5549,
#  5552,
#  5553,
#  5554,
#  5558,
#  5563,
#  5566,
#  5583,
#  5587,
#  5591,
#  5600,
#  5601,
#  5602,
#  5603,
#  5604,
#  5605,
#  5621,
#  5689,
#  5721,
#  5724,
#  5772,
#  5786,
#  5842,
#  5905,
#  6046,
#  6084,
#  6101,
#  6117,
#  6120,
#  6127,
#  6143,
#  6144,
#  6145,
#  6146,
#  6148,
#  6149,
#  6150,
#  6151,
#  6152,
#  6155,
#  6212,
#  6259,
#  6287,
#  6342,
#  6404,
#  6465,
#  6487,
#  6582,
#  6587,
#  6661,
#  6779,
#  6826,
#  6830,
#  6840,
#  6930,
#  6988,
#  7033,
#  7039,
#  7041,
#  7045,
#  7046,
#  7049,
#  7053,
#  7058,
#  7059,
#  7060,
#  7063,
#  7066,
#  7102,
#  7135,
#  7151,
#  7419,
#  7459,
#  7477,
#  7569,
#  7669,
#  7791,
#  7845,
#  7858,
#  7916,
#  8028,
#  8155,
#  8176,
#  8277,
#  8448,
#  8511,
#  8760,
#  8789,
#  8911,
#  8917,
#  8927,
#  8934,
#  8950,
#  8955,
#  9008,
#  9026,
#  9029,
#  9035,
#  9038,
#  9046,
#  9135,
#  9195,
#  9340,
#  9341,
#  9348,
#  9397,
#  9460,
#  9589,
#  9611,
#  9643,
#  9651,
#  9725,
#  9852,
#  9946,
#  9982,
#  10104,
#  10127,
#  10149,
#  10244,
#  10272,
#  10358,
#  10369,
#  10370,
#  10457,
#  10491,
#  10530,
#  10554,
#  10649,
#  10694,
#  10817,
#  10841,
#  10995,
#  11041,
#  11185,
#  11240,
#  11369,
#  11456,
#  11465,
#  11574,
#  11586,
#  11658,
#  11700,
#  11730,
#  11749,
#  11750,
#  11761,
#  11765,
#  11799,
#  11804,
#  11806,
#  11821,
#  11856,
#  11881,
#  11935,
#  12009,
#  12018,
#  12295,
#  12309,
#  12314,
#  12320,
#  12324,
#  12331,
#  12345,
#  12346,
#  12354,
#  12359,
#  12367,
#  12382,
#  12384,
#  12385,
#  12386,
#  12390,
#  12496,
#  12501,
#  12577,
#  12589,
#  12602,
#  12614,
#  12657,
#  12665,
#  12711,
#  12845,
#  12890,
#  12907,
#  12918,
#  12953,
#  12958,
#  13008,
#  13033,
#  13043,
#  13119,
#  13177,
#  13237,
#  13240,
#  13376,
#  13405,
#  13411,
#  13439,
#  13483,
#  13522,
#  13532,
#  13533,
#  13538,
#  13540,
#  13542,
#  13545,
#  13547,
#  13549,
#  13551,
#  13553,
#  13554,
#  13555,
#  13556,
#  13558,
#  13560,
#  13562,
#  13564,
#  13566,
#  13569,
#  13572,
#  13574,
#  13682,
#  13767,
#  13823,
#  13824,
#  13826,
#  13833,
#  13835,
#  13836,
#  13838,
#  13883,
#  13895,
#  13915,
#  13927,
#  13942,
#  13960,
#  13992,
#  13994,
#  14001,
#  14033,
#  14055,
#  14072,
#  14093,
#  14101,
#  14108,
#  14123,
#  14129,
#  14135,
#  14143,
#  14160,
#  14198,
#  14199,
#  14225,
#  14255,
#  14292,
#  14315,
#  14322,
#  14508,
#  14529,
#  14550,
#  14567,
#  14586,
#  14589,
#  14603,
#  14615,
#  14650,
#  14673,
#  14681,
#  14689]

# %%
df = df.drop(labels=non_int_date_index, axis=0)

# %%
df.head(116)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 111                   3.94          male
# 112                   4.06          male
# 113                   3.83        female
# 114                   4.21          male
# 116                   3.82          male
#
#                                          author_genres  author_id  \
# 0                                  historical-fiction,      74489
# 1                literature-fiction,mystery-thrillers,     706255
# 2                                             romance,    5618190
# 3                                      fiction,memoir,      37871
# 4                                 young-adult,fantasy,      36122
# ..                                                 ...        ...
# 111               literature-fiction,political-satire,      43298
# 112                                       young-adult,    2987125
# 113                           science-fiction-fantasy,       1318
# 114  science-fiction-fantasy,mystery-thrillers,comi...      32595
# 116  literature-fiction,science-fiction-fantasy,his...     880695
#
#                author_name                           author_page_url  \
# 0      Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1          Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3            José Donoso\n             /author/show/37871.Jos_Donoso
# 4      Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# ..                     ...                                       ...
# 111     Yevgeny Zamyatin\n       /author/show/43298.Yevgeny_Zamyatin
# 112           Kiera Cass\n           /author/show/2987125.Kiera_Cass
# 113   Susan Beth Pfeffer\n      /author/show/1318.Susan_Beth_Pfeffer
# 114       Koushun Takami\n         /author/show/32595.Koushun_Takami
# 116           H.G. Wells\n             /author/show/880695.H_G_Wells
#
#      author_rating_count  author_review_count                birthplace  \
# 0                  74399                 6268       United States\n
# 1                3726435               142704              Sweden\n
# 2                  76496                 7975         United States\n
# 3                   5522                  489               Chile\n
# 4                 291013                13453       United States\n
# ..                   ...                  ...                       ...
# 111                57629                 3642  Russian Federation\n
# 112              1839977               137339    \n   United States\n
# 113               180909                16831         United States\n
# 114                70232                 5167               Japan\n
# 116               883702                29259      United Kingdom\n
#
#      book_average_rating                                       book_fullurl  \
# 0                   4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                   4.13  https://www.goodreads.com/book/show/2429135.Th...
# 2                   3.99  https://www.goodreads.com/book/show/27833684-t...
# 3                   4.14  https://www.goodreads.com/book/show/382975.The...
# 4                   4.01  https://www.goodreads.com/book/show/64207.Sorc...
# ..                   ...                                                ...
# 111                 3.94       https://www.goodreads.com/book/show/76171.We
# 112                 4.14  https://www.goodreads.com/book/show/10507293-t...
# 113                 3.89  https://www.goodreads.com/book/show/213753.Lif...
# 114                 4.25  https://www.goodreads.com/book/show/57891.Batt...
# 116                 3.88  https://www.goodreads.com/book/show/2493.The_T...
#
#       book_id                                         book_title      genre_1  \
# 0      686717               \n      Murder on St. Mark's Place\n      Mystery
# 1     2429135          \n      The Girl with the Dragon Tattoo\n      Fiction
# 2    27833684                     \n      Tailored for Trouble\n      Romance
# 3      382975                \n      The Obscene Bird of Night\n      Fiction
# 4       64207  \n      Sorcery & Cecelia: or The Enchanted Ch...      Fantasy
# ..        ...                                                ...          ...
# 111     76171                                       \n      We\n      Fiction
# 112  10507293                            \n      The Selection\n  Young Adult
# 113    213753                       \n      Life As We Knew It\n  Young Adult
# 114     57891                            \n      Battle Royale\n      Fiction
# 116      2493                         \n      The Time Machine\n     Classics
#
#              genre_2  num_ratings  num_reviews pages publish_date  score
# 0         Historical         5260          375   277         2000   3230
# 1            Mystery      2229163        65227   465         2005   3062
# 2       Contemporary         2151          391   354         2016   4585
# 3    Magical Realism         1844          173   438         1970   1533
# 4        Young Adult        17051         1890   326         1988   2105
# ..               ...          ...          ...   ...          ...    ...
# 111  Science Fiction        56166         3559   255         1921  47660
# 112          Romance       692298        41032   336         2012  48069
# 113  Science Fiction       105209         9049   337         2006  48468
# 114  Science Fiction        46082         4365   617         1999  52756
# 116  Science Fiction       349223         8865   118         1895  62021
#
# [116 rows x 20 columns]

# %%
df.shape
# Out:
# (14296, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']

# %%
##########################
##make sure female and male
##########################

# %%
correct_gender_index = []
a = 0
for i in range(len(df['author_gender'])):
    if not (df['author_gender'][i] == 'female' or 'male'):
            correct_gender_index.append(i)
            a+=1
            #non_int_date_index.append(df['publish_date'][i])
correct_gender_index
a
# Out:
# 0

# %%
df['birthplace'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['book_title'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['author_name'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['birthplace'] = df['birthplace'].str.strip()
df['book_title'] = df['book_title'].str.strip()
df['author_genres'] = df['author_genres'].str.replace(',+$', '')
df['publish_date'] = df['publish_date'].replace(r'^\s*$', np.nan, regex=True)
df['publish_date'] = df['publish_date'].str[-4:]
df['publish_date'] = df['publish_date'].replace('by', np.nan, regex=True)
df['birthplace']=df['birthplace'].replace(r'^\s*$', np.nan, regex=True)
df['publish_date'] = pd.to_numeric(df['publish_date'], errors='coerce')
df['book_id'] = df['book_id'].str.extract('(\d+)', expand=False)
df['book_id'] = df['book_id'].astype(int)
df['pages'] = df['pages'].str.extract('(\d+)', expand=False)
df['pages'] = df['pages'].astype(int)
# Out:
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_88556/3043886896.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['author_genres'] = df['author_genres'].str.replace(',+$', '')

# %%
holder = []
for i in range(len(df)):
    holder.append(df["genre_1"][i])
    holder.append(df["genre_2"][i])
#     print(holder)
    holder.sort()
#     print(holder)
    df["genre_1"][i] = holder[0]
    df["genre_2"][i] = holder[1]
    holder = []
# Out:
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_88556/1300805553.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["genre_1"][i] = holder[0]
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_88556/1300805553.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["genre_2"][i] = holder[1]

# %%
# df.loc[111]

# %%
df.to_csv('/Users/zhenweiliu/Desktop/ECE225A/cleaned_book_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dfold = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/cleaned_book_data.csv')
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/Preprocessed_data1.csv')
book = df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/Preprocessed_data1.csv')
print(df.shape)
# Out:
# (126674, 9)

# %%
# def clean(df, col=None):

#     """
#     data clean up
#     :param df: pd data frame
#     :param col: clean up column
#     :return: df: pd data fram 
#     """

#     for i in df.columns:
#         if i in col:
#             df[i] = df[i].str.replace('\n', '', regex=False)
#     return df

# %%
# clean_up_col = ['author_name','book_title']
# df = clean(df,clean_up_col)
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/cleaned_book_data.csv')

# %%
author_genres = df['genre_1'].values
all_genres = []
for i in author_genres:
    if ',' in i:
        temp = i.split(',')
        for t in temp:
            all_genres.append(t)
    else:
        all_genres.append(i)

genres_df = pd.DataFrame(all_genres)
genres_df.columns = ['genres']
genres_df.head()

pic_gen = pd.DataFrame(genres_df['genres'].value_counts())
pic_gen = pic_gen.reset_index(drop=False)
pic_gen.columns = ['genres','genres_num']
pic_gen.head()

# plt.figure(figsize=(32,10))
# sns.barplot(x='genres',y='genres_num',data=pic_gen.iloc[:20,:])
# plt.title('Genres Distribution')
# plt.show()

fig,ax = plt.subplots(figsize=(12,15))
textprops = {"fontsize":20}
plt.pie(x='genres_num',labels='genres',autopct = '%.1f%%',data=pic_gen.iloc[:10,:],textprops =textprops)
ax.set_title('Genres Distribution', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(10,8))
scores = df['author_average_rating'].values
# x轴直方图
sns.histplot(data=df,x='author_average_rating')
plt.title('Author_average_rating Distribution')
plt.show()

# %%
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/Preprocessed_data1.csv')
df['year'] = pd.DatetimeIndex(df['year_of_publication']).year
df

# df['year_of_publication'] = int(df['year_of_publication'])
# df.dtypes

df["year_of_publication"] = pd.to_numeric(df["year_of_publication"],downcast='integer')
df
# Out:
#         Unnamed: 0                                         book_title  \
# 0                0                                Classical Mythology
# 1                1                                       Clara Callan
# 2               15                               Decision in Normandy
# 3               18  Flu: The Story of the Great Influenza Pandemic...
# 4               29                             The Mummies of Urumchi
# ...            ...                                                ...
# 126669     1031166                            Secret of Willow Castle
# 126670     1031168  The Military Quotation Book : Revised and Expa...
# 126671     1031170  As Hogan Said . . . : The 389 Best Things Anyo...
# 126672     1031171  All Elevations Unknown: An Adventure in the He...
# 126673     1031173  The Are You Being Served? Stories: 'Camping In...
#
#                  book_author  year_of_publication                publisher  \
# 0         Mark P. O. Morford                 2002  Oxford University Press
# 1       Richard Bruce Wright                 2001    HarperFlamingo Canada
# 2               Carlo D'Este                 1991          HarperPerennial
# 3           Gina Bari Kolata                 1999     Farrar Straus Giroux
# 4            E. J. W. Barber                 1999   W. W. Norton & Company
# ...                      ...                  ...                      ...
# 126669               Ly Cook                 1911        Firefly Books Ltd
# 126670        James Charlton                 2002       Thomas Dunne Books
# 126671        Randy Voorhees                 2000         Simon & Schuster
# 126672          Sam Lightner                 2001           Broadway Books
# 126673          Jeremy Lloyd                 1997               Kqed Books
#
#                                                     img_s  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 126669  http://images.amazon.com/images/P/0920656307.0...
# 126670  http://images.amazon.com/images/P/0312266448.0...
# 126671  http://images.amazon.com/images/P/0743203763.0...
# 126672  http://images.amazon.com/images/P/0767907566.0...
# 126673  http://images.amazon.com/images/P/0912333022.0...
#
#                                                     img_m  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 126669  http://images.amazon.com/images/P/0920656307.0...
# 126670  http://images.amazon.com/images/P/0312266448.0...
# 126671  http://images.amazon.com/images/P/0743203763.0...
# 126672  http://images.amazon.com/images/P/0767907566.0...
# 126673  http://images.amazon.com/images/P/0912333022.0...
#
#                                                     img_l  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 126669  http://images.amazon.com/images/P/0920656307.0...
# 126670  http://images.amazon.com/images/P/0312266448.0...
# 126671  http://images.amazon.com/images/P/0743203763.0...
# 126672  http://images.amazon.com/images/P/0767907566.0...
# 126673  http://images.amazon.com/images/P/0912333022.0...
#
#                                                   Summary  year
# 0       Provides an introduction to classical myths pl...  1970
# 1       In a small town in Canada, Clara Callan reluct...  1970
# 2       Here, for the first time in paperback, is an o...  1970
# 3       Describes the great flu epidemic of 1918, an o...  1970
# 4       A look at the incredibly well-preserved ancien...  1970
# ...                                                   ...   ...
# 126669  Canadian story early 19th century Orphaned ser...  1970
# 126670  Contains more than 1,200 quotations about war,...  1970
# 126671  Golf lovers will revel in this collection of t...  1970
# 126672  A daring twist on the travel-adventure genre t...  1970
# 126673  These hilarious stories by the creator of publ...  1970
#
# [126674 rows x 10 columns]

# %%
plt.figure(figsize=(12, 8))

textprops = {"fontsize":20}
x = df.groupby(['year_of_publication'])["book_title"].count().sort_values(ascending=False).head(10)

sns.set(style="whitegrid",font_scale = 2)
ax = sns.barplot(x=x.index, y=x)
ax.set_title('Top 10 published year',fontsize=25)
ax.set_ylabel('Number of books',fontsize=20)
ax.set_xlabel('Year',fontsize=20)
# Out:
# Text(0.5, 0, 'Year')

# %%
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE225A/cleaned_book_data.csv')
score_labels = pd.cut(df['author_average_rating'],4,precision=2)
# score_labels.value_counts()
plt.figure(figsize=(8,10))
patches,l_text,p_text= plt.pie(x=score_labels.value_counts(),labels=score_labels.value_counts().index,autopct = '%.1f%%')
for t in l_text:
    t.set_size(10)
plt.title('Scores Pie Distribution')
plt.show()
